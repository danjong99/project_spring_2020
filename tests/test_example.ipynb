# %%
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from bk_packages.shrinkmtx import rand_draw, shrunken_mtx

# %%
DATA_FOLDER="/Users/kangb3/github/project_spring_2020/tests/data/"
EXP_FNAME = os.path.join(DATA_FOLDER, "exprs_mtx.txt")
META_FNAME = os.path.join(DATA_FOLDER, "metatable.txt")
    
#### Read Meta Files - read as list of lists
meta = []
with open(META_FNAME) as f_obj:
     for line in f_obj:
        res = line.replace('"','').strip('\n').split('\t')
        meta.append(res)
    
### Insert one element in the 1th list of the meta data
meta[0].insert(0,'rowname')
    
### Read matrix file - read as list of lists
mtx = []
with open(EXP_FNAME) as f_obj:
    for line in f_obj:
        res = line.replace('"','').strip('\n').split('\t')
        mtx.append(res)
    
### Insert one element in the 1th list of the mtx
mtx[0].insert(0,'gene')

# %%
meta
# Out:
# [['rowname', 'cell.id', 'cluster', 'orig.cell.id', 'tSNE_1', 'tSNE_2'],
#  ['GF_TAGCAAGTTTGN',
#   'TAGCAAGTTTGN',
#   '5',
#   'GF_TAGCAAGTTTGN',
#   '-40.5955451010004',
#   '8.23491567760055'],
#  ['GF_AAGCGTGGCTCN',
#   'AAGCGTGGCTCN',
#   '5',
#   'GF_AAGCGTGGCTCN',
#   '-35.4161278828313',
#   '8.72893509260779'],
#  ['GF_GGCATTTCCTTT',
#   'GGCATTTCCTTT',
#   '5',
#   'GF_GGCATTTCCTTT',
#   '-39.2494103364834',
#   '11.2516716483934'],
#  ['GF_GGGCTCCGAGAC',
#   'GGGCTCCGAGAC',
#   '5',
#   'GF_GGGCTCCGAGAC',
#   '-42.1311056708132',
#   '5.34413703850037'],
#  ['GF_AGAGTCCAAACC',
#   'AGAGTCCAAACC',
#   '5',
#   'GF_AGAGTCCAAACC',
#   '-39.8181658156667',
#   '7.48557316159793'],
#  ['GF_CACCCCACGCCN',
#   'CACCCCACGCCN',
#   '5',
#   'GF_CACCCCACGCCN',
#   '-40.8141842102234',
#   '7.38739457341958'],
#  ['GF_GAAATATGTTGC',
#   'GAAATATGTTGC',
#   '5',
#   'GF_GAAATATGTTGC',
#   '-40.1979418946075',
#   '4.1008792229603'],
#  ['GF_AGATTAGTCCCN',
#   'AGATTAGTCCCN',
#   '5',
#   'GF_AGATTAGTCCCN',
#   '-35.7662315703122',
#   '1.29284971221496'],
#  ['GF_GATGTCGATTGN',
#   'GATGTCGATTGN',
#   '5',
#   'GF_GATGTCGATTGN',
#   '-37.4657765391025',
#   '3.22425131330233'],
#  ['GF_TGGTTTCGCCCN',
#   'TGGTTTCGCCCN',
#   '5',
#   'GF_TGGTTTCGCCCN',
#   '-35.6920215960362',
#   '8.48515259504419'],
#  ['GF_CTGGCCCGTACC',
#   'CTGGCCCGTACC',
#   '5',
#   'GF_CTGGCCCGTACC',
#   '-36.9322657248613',
#   '2.93834212297413'],
#  ['GF_CCTCCAGCTTAN',
#   'CCTCCAGCTTAN',
#   '10',
#   'GF_CCTCCAGCTTAN',
#   '-25.1775503706478',
#   '2.69963778193002'],
#  ['GF_AACCTTCGCAGT',
#   'AACCTTCGCAGT',
#   '5',
#   'GF_AACCTTCGCAGT',
#   '-41.1184917006476',
#   '3.6231790152819'],
#  ['GF_CGTTTCGGCGAG',
#   'CGTTTCGGCGAG',
#   '5',
#   'GF_CGTTTCGGCGAG',
#   '-35.089365110104',
#   '12.9269007990093'],
#  ['GF_CATACCAGCATC',
#   'CATACCAGCATC',
#   '5',
#   'GF_CATACCAGCATC',
#   '-39.547010961882',
#   '6.07621889669294'],
#  ['GF_CCCATACGAACG',
#   'CCCATACGAACG',
#   '5',
#   'GF_CCCATACGAACG',
#   '-39.2126051715292',
#   '11.364264259114'],
#  ['GF_TATTTTGTGTTN',
#   'TATTTTGTGTTN',
#   '5',
#   'GF_TATTTTGTGTTN',
#   '-39.8599117650581',
#   '6.64085860029263'],
#  ['GF_GAGTAACTGTGN',
#   'GAGTAACTGTGN',
#   '5',
#   'GF_GAGTAACTGTGN',
#   '-38.5302854363367',
#   '10.1201378157655'],
#  ['GF_CAGCTTAACGAN',
#   'CAGCTTAACGAN',
#   '5',
#   'GF_CAGCTTAACGAN',
#   '-38.8106940639618',
#   '8.79816977222167'],
#  ['GF_ACGGAAGTTCCC',
#   'ACGGAAGTTCCC',
#   '5',
#   'GF_ACGGAAGTTCCC',
#   '-39.2715059032659',
#   '5.26914781392599'],
#  ['GF_GTGTGCTAGACA',
#   'GTGTGCTAGACA',
#   '5',
#   'GF_GTGTGCTAGACA',
#   '-41.2530704641131',
#   '5.80171270787575'],
#  ['GF_TGATTAAAATTC',
#   'TGATTAAAATTC',
#   '5',
#   'GF_TGATTAAAATTC',
#   '-37.2755487521397',
#   '-0.488072440755321'],
#  ['GF_GAGTACCCTCGC',
#   'GAGTACCCTCGC',
#   '5',
#   'GF_GAGTACCCTCGC',
#   '-34.3800931560576',
#   '10.3938790628356'],
#  ['GF_GTCCGCCGTGCC',
#   'GTCCGCCGTGCC',
#   '5',
#   'GF_GTCCGCCGTGCC',
#   '-33.8165567713502',
#   '7.54566918229976'],
#  ['GF_AGGTTCGCCTTT',
#   'AGGTTCGCCTTT',
#   '5',
#   'GF_AGGTTCGCCTTT',
#   '-34.6780605364685',
#   '5.40103811059408'],
#  ['GF_AATGCTACCAAN',
#   'AATGCTACCAAN',
#   '5',
#   'GF_AATGCTACCAAN',
#   '-33.8937265733813',
#   '4.30318220807588'],
#  ['GF_AACCTCGATTCC',
#   'AACCTCGATTCC',
#   '5',
#   'GF_AACCTCGATTCC',
#   '-40.3310432335007',
#   '9.46613614779739'],
#  ['GF_CACAAATGGACA',
#   'CACAAATGGACA',
#   '5',
#   'GF_CACAAATGGACA',
#   '-32.8841072279346',
#   '8.45466788806149'],
#  ['GF_ACGTTCACACAT',
#   'ACGTTCACACAT',
#   '5',
#   'GF_ACGTTCACACAT',
#   '-39.6047036057623',
#   '9.67807928207249'],
#  ['GF_CGTTAGAACACN',
#   'CGTTAGAACACN',
#   '5',
#   'GF_CGTTAGAACACN',
#   '-31.001533086512',
#   '3.33863280179371'],
#  ['GF_AGATGGCAGGTC',
#   'AGATGGCAGGTC',
#   '5',
#   'GF_AGATGGCAGGTC',
#   '-34.1034786482852',
#   '6.50646370960451'],
#  ['GF_TGAGGTAGCCAN',
#   'TGAGGTAGCCAN',
#   '5',
#   'GF_TGAGGTAGCCAN',
#   '-40.4334385594264',
#   '1.5002666917929'],
#  ['GF_GTTGTTGGTGCN',
#   'GTTGTTGGTGCN',
#   '5',
#   'GF_GTTGTTGGTGCN',
#   '-39.7681439058463',
#   '8.9789696503241'],
#  ['GF_GCTGGCGTCGGG',
#   'GCTGGCGTCGGG',
#   '5',
#   'GF_GCTGGCGTCGGG',
#   '-37.6944397077441',
#   '8.62688707864602'],
#  ['GF_CGAAGGCTGTCN',
#   'CGAAGGCTGTCN',
#   '5',
#   'GF_CGAAGGCTGTCN',
#   '-40.2454795331442',
#   '5.9307455830084'],
#  ['GF_TTCATTTCTTCN',
#   'TTCATTTCTTCN',
#   '5',
#   'GF_TTCATTTCTTCN',
#   '-39.7879358378764',
#   '7.54544394766721'],
#  ['GF_CGTGCGGAAACG',
#   'CGTGCGGAAACG',
#   '10',
#   'GF_CGTGCGGAAACG',
#   '-23.1125471149106',
#   '-1.45506351674558'],
#  ['GF_ACGCCACATTTA',
#   'ACGCCACATTTA',
#   '5',
#   'GF_ACGCCACATTTA',
#   '-33.7014071015354',
#   '1.70717249324149'],
#  ['GF_AGTCGTGAGCTA',
#   'AGTCGTGAGCTA',
#   '5',
#   'GF_AGTCGTGAGCTA',
#   '-33.3911776575305',
#   '5.89827301922092'],
#  ['GF_CGTCTAAAGATC',
#   'CGTCTAAAGATC',
#   '5',
#   'GF_CGTCTAAAGATC',
#   '-38.0300225624955',
#   '2.67129135159903'],
#  ['GF_CGGACAGGGTCN',
#   'CGGACAGGGTCN',
#   '5',
#   'GF_CGGACAGGGTCN',
#   '-34.7968693274935',
#   '2.47546870658343'],
#  ['GF_GTAACAATATTA',
#   'GTAACAATATTA',
#   '5',
#   'GF_GTAACAATATTA',
#   '-37.3655469900371',
#   '3.36460668027076'],
#  ['GF_ATGCCATGTGTC',
#   'ATGCCATGTGTC',
#   '5',
#   'GF_ATGCCATGTGTC',
#   '-36.755763577756',
#   '6.9083122676348'],
#  ['GF_AATCCAGAGCAN',
#   'AATCCAGAGCAN',
#   '5',
#   'GF_AATCCAGAGCAN',
#   '-38.1782886749499',
#   '1.14423283064531'],
#  ['GF_ACCTGCTATGTG',
#   'ACCTGCTATGTG',
#   '5',
#   'GF_ACCTGCTATGTG',
#   '-39.4595644339237',
#   '-2.58702631227528'],
#  ['GF_TGAGCCTTCTAT',
#   'TGAGCCTTCTAT',
#   '5',
#   'GF_TGAGCCTTCTAT',
#   '-38.6143748840188',
#   '5.81972924071286'],
#  ['GF_AGTGTAGCCGCN',
#   'AGTGTAGCCGCN',
#   '5',
#   'GF_AGTGTAGCCGCN',
#   '-39.4200998581003',
#   '8.85326577140917'],
#  ['GF_CAAATGTAGGTG',
#   'CAAATGTAGGTG',
#   '5',
#   'GF_CAAATGTAGGTG',
#   '-34.2847111520325',
#   '0.00306276362150344'],
#  ['GF_GATTTACGATAN',
#   'GATTTACGATAN',
#   '5',
#   'GF_GATTTACGATAN',
#   '-29.9158087125728',
#   '1.7280576356376'],
#  ['GF_GCATTGGTGGTA',
#   'GCATTGGTGGTA',
#   '5',
#   'GF_GCATTGGTGGTA',
#   '-37.5485864957273',
#   '9.46491920851099'],
#  ['GF_AGAATTCGGTGC',
#   'AGAATTCGGTGC',
#   '10',
#   'GF_AGAATTCGGTGC',
#   '-24.0080754582588',
#   '1.8634135144018'],
#  ['GF_GCGTAGCCACTT',
#   'GCGTAGCCACTT',
#   '9',
#   'GF_GCGTAGCCACTT',
#   '-40.1009611617983',
#   '-1.89400897957149'],
#  ['GF_CTCTAGAGACCC',
#   'CTCTAGAGACCC',
#   '10',
#   'GF_CTCTAGAGACCC',
#   '-24.1706917453203',
#   '0.380049228124812'],
#  ['GF_ATGGTCACCGAG',
#   'ATGGTCACCGAG',
#   '5',
#   'GF_ATGGTCACCGAG',
#   '-36.4736904887229',
#   '1.89380915353536'],
#  ['GF_TTGACCAAAGCN',
#   'TTGACCAAAGCN',
#   '5',
#   'GF_TTGACCAAAGCN',
#   '-27.1100176691195',
#   '1.48543883579999'],
#  ['GF_ACGAGCGCACCT',
#   'ACGAGCGCACCT',
#   '5',
#   'GF_ACGAGCGCACCT',
#   '-36.1056521746349',
#   '10.4136188380993'],
#  ['GF_CCAAGTAACTTT',
#   'CCAAGTAACTTT',
#   '5',
#   'GF_CCAAGTAACTTT',
#   '-36.8745197507187',
#   '3.09944524943476'],
#  ['GF_GGCATATAATGN',
#   'GGCATATAATGN',
#   '10',
#   'GF_GGCATATAATGN',
#   '-19.7903878052335',
#   '-5.47573310207287'],
#  ['GF_AACATGAAGGAG',
#   'AACATGAAGGAG',
#   '5',
#   'GF_AACATGAAGGAG',
#   '-33.9188496900524',
#   '6.97101534726501'],
#  ['GF_TGAAGTAATGCA',
#   'TGAAGTAATGCA',
#   '5',
#   'GF_TGAAGTAATGCA',
#   '-35.8629100758957',
#   '5.41824903785258'],
#  ['GF_TATAAGCCTTAA',
#   'TATAAGCCTTAA',
#   '5',
#   'GF_TATAAGCCTTAA',
#   '-38.7062864349758',
#   '8.81219412320339'],
#  ['GF_GCGGTCGTGCCT',
#   'GCGGTCGTGCCT',
#   '5',
#   'GF_GCGGTCGTGCCT',
#   '-37.6590967955252',
#   '4.13525598301494'],
#  ['GF_ACATTAGTTCTA',
#   'ACATTAGTTCTA',
#   '5',
#   'GF_ACATTAGTTCTA',
#   '-32.6897118133473',
#   '0.350070721861615'],
#  ['GF_CGCACAATCGAA',
#   'CGCACAATCGAA',
#   '5',
#   'GF_CGCACAATCGAA',
#   '-36.9765593409761',
#   '3.3601268802585'],
#  ['GF_TGTTAGCCGGCG',
#   'TGTTAGCCGGCG',
#   '5',
#   'GF_TGTTAGCCGGCG',
#   '-33.4520613404477',
#   '1.21416259938202'],
#  ['GF_CGTCCGTGTAAC',
#   'CGTCCGTGTAAC',
#   '5',
#   'GF_CGTCCGTGTAAC',
#   '-35.9683453405268',
#   '2.07298893002122'],
#  ['GF_TTGATAGAGCAG',
#   'TTGATAGAGCAG',
#   '5',
#   'GF_TTGATAGAGCAG',
#   '-38.3077645130907',
#   '3.63852658166928'],
#  ['GF_CGATCCTGGCCC',
#   'CGATCCTGGCCC',
#   '5',
#   'GF_CGATCCTGGCCC',
#   '-35.9129225667306',
#   '1.30664787942634'],
#  ['GF_TTAGCTTAACCG',
#   'TTAGCTTAACCG',
#   '5',
#   'GF_TTAGCTTAACCG',
#   '-25.8346280134884',
#   '-10.4479944050244'],
#  ['GF_TCAAGACAGTAA',
#   'TCAAGACAGTAA',
#   '5',
#   'GF_TCAAGACAGTAA',
#   '-36.6230343924841',
#   '8.23262805672111'],
#  ['GF_GCTCGAGCGCCT',
#   'GCTCGAGCGCCT',
#   '5',
#   'GF_GCTCGAGCGCCT',
#   '-36.1975786854698',
#   '6.14416096085272'],
#  ['GF_GTCAAGTGTCAN',
#   'GTCAAGTGTCAN',
#   '5',
#   'GF_GTCAAGTGTCAN',
#   '-28.5349912117345',
#   '2.19977723781503'],
#  ['GF_AAGCTAGATAGN',
#   'AAGCTAGATAGN',
#   '5',
#   'GF_AAGCTAGATAGN',
#   '-26.7179762521888',
#   '-0.744501179014321'],
#  ['GF_CTGGCCGAACCT',
#   'CTGGCCGAACCT',
#   '5',
#   'GF_CTGGCCGAACCT',
#   '-26.8705119977894',
#   '0.680692251948886'],
#  ['GF_GTAGATGGTGCC',
#   'GTAGATGGTGCC',
#   '5',
#   'GF_GTAGATGGTGCC',
#   '-37.4650952283868',
#   '7.30581360987424'],
#  ['GF_CGTTTCATGTAA',
#   'CGTTTCATGTAA',
#   '5',
#   'GF_CGTTTCATGTAA',
#   '-30.3672123332162',
#   '7.58967786040871'],
#  ['GF_GCCCTCACCTGC',
#   'GCCCTCACCTGC',
#   '5',
#   'GF_GCCCTCACCTGC',
#   '-35.9666873956548',
#   '1.83729711553345'],
#  ['GF_CGCAGACATGCA',
#   'CGCAGACATGCA',
#   '5',
#   'GF_CGCAGACATGCA',
#   '-29.9997716315634',
#   '6.82088463283915'],
#  ['GF_AAACTCGCGAAA',
#   'AAACTCGCGAAA',
#   '9',
#   'GF_AAACTCGCGAAA',
#   '-41.2896974119817',
#   '-3.72220054904604'],
#  ['GF_ACCCCAAGACGN',
#   'ACCCCAAGACGN',
#   '5',
#   'GF_ACCCCAAGACGN',
#   '-27.1105630930001',
#   '1.5235957466597'],
#  ['GF_AGGATCTTTCGA',
#   'AGGATCTTTCGA',
#   '5',
#   'GF_AGGATCTTTCGA',
#   '-34.9513234892066',
#   '7.1319672314165'],
#  ['GF_ACTCCTCAGTCG',
#   'ACTCCTCAGTCG',
#   '5',
#   'GF_ACTCCTCAGTCG',
#   '-37.4597224228026',
#   '2.9321677703414'],
#  ['GF_TATATAGTGCTC',
#   'TATATAGTGCTC',
#   '5',
#   'GF_TATATAGTGCTC',
#   '-27.5978750493895',
#   '0.64408563491251'],
#  ['GF_CACCAGGTGAAC',
#   'CACCAGGTGAAC',
#   '5',
#   'GF_CACCAGGTGAAC',
#   '-34.7082276942061',
#   '4.5478625229382'],
#  ['GF_AGTGATACCGGC',
#   'AGTGATACCGGC',
#   '5',
#   'GF_AGTGATACCGGC',
#   '-35.5741992690686',
#   '2.35836064356155'],
#  ['GF_TAGGAGTTCCTT',
#   'TAGGAGTTCCTT',
#   '5',
#   'GF_TAGGAGTTCCTT',
#   '-38.9117315724512',
#   '3.29059981611879'],
#  ['GF_AGAGTGGCGGCA',
#   'AGAGTGGCGGCA',
#   '5',
#   'GF_AGAGTGGCGGCA',
#   '-28.5184631396975',
#   '2.28725258472724'],
#  ['GF_GGTGGCGGTCAN',
#   'GGTGGCGGTCAN',
#   '5',
#   'GF_GGTGGCGGTCAN',
#   '-35.2912771169443',
#   '4.51837983951726'],
#  ['GF_CCGAAGGTGGTN',
#   'CCGAAGGTGGTN',
#   '5',
#   'GF_CCGAAGGTGGTN',
#   '-38.805184696855',
#   '3.23256282940486'],
#  ['GF_GTTGGAACAGTG',
#   'GTTGGAACAGTG',
#   '5',
#   'GF_GTTGGAACAGTG',
#   '-28.2686871410122',
#   '4.64775910131241'],
#  ['GF_TAAGTATTCCGA',
#   'TAAGTATTCCGA',
#   '5',
#   'GF_TAAGTATTCCGA',
#   '-32.9946999468671',
#   '3.43524666746159'],
#  ['GF_AGTAGACTGTCG',
#   'AGTAGACTGTCG',
#   '5',
#   'GF_AGTAGACTGTCG',
#   '-28.6430166934992',
#   '6.07579314379544'],
#  ['GF_GGTCCCAACAGC',
#   'GGTCCCAACAGC',
#   '5',
#   'GF_GGTCCCAACAGC',
#   '-26.4493676190744',
#   '0.375952676212128'],
#  ['GF_GGGGAACAACAC',
#   'GGGGAACAACAC',
#   '5',
#   'GF_GGGGAACAACAC',
#   '-29.2134459402255',
#   '5.20505454914003'],
#  ['GF_GGGTAGCTCCTC',
#   'GGGTAGCTCCTC',
#   '5',
#   'GF_GGGTAGCTCCTC',
#   '-34.9197452181691',
#   '3.03148358978217'],
#  ['GF_CACTTACAAGGT',
#   'CACTTACAAGGT',
#   '5',
#   'GF_CACTTACAAGGT',
#   '-25.7750633286052',
#   '-1.28714221520466'],
#  ['GF_TTCTGCCCGTGG',
#   'TTCTGCCCGTGG',
#   '5',
#   'GF_TTCTGCCCGTGG',
#   '-30.2496149189016',
#   '-2.23961858620892'],
#  ['GF_GTCAAGTGTCAT',
#   'GTCAAGTGTCAT',
#   '5',
#   'GF_GTCAAGTGTCAT',
#   '-33.3921843552387',
#   '5.67297609539584'],
#  ['GF_CGCAAAAGCTTN',
#   'CGCAAAAGCTTN',
#   '5',
#   'GF_CGCAAAAGCTTN',
#   '-41.0639940410946',
#   '3.0110566359855'],
#  ['GF_AGCGTGCGGGAA',
#   'AGCGTGCGGGAA',
#   '5',
#   'GF_AGCGTGCGGGAA',
#   '-29.3382180081962',
#   '3.22917130204328'],
#  ['GF_AAACTTTGTAAC',
#   'AAACTTTGTAAC',
#   '5',
#   'GF_AAACTTTGTAAC',
#   '-34.8623580985759',
#   '-0.350895662834052'],
#  ['GF_GTTTTCGGCTAN',
#   'GTTTTCGGCTAN',
#   '5',
#   'GF_GTTTTCGGCTAN',
#   '-33.3728401562127',
#   '0.772085377347905'],
#  ['GF_ACGCCTCGGACT',
#   'ACGCCTCGGACT',
#   '10',
#   'GF_ACGCCTCGGACT',
#   '-23.7909919186047',
#   '0.0145154230026243'],
#  ['WT_ATCATGAGGCAG',
#   'ATCATGAGGCAG',
#   '5',
#   'WT_ATCATGAGGCAG',
#   '-31.3758193636581',
#   '11.7157578000934'],
#  ['WT_TCGCCTCGAGTG',
#   'TCGCCTCGAGTG',
#   '5',
#   'WT_TCGCCTCGAGTG',
#   '-30.2186076918237',
#   '10.077589515077'],
#  ['WT_GGACCGCGTTTA',
#   'GGACCGCGTTTA',
#   '5',
#   'WT_GGACCGCGTTTA',
#   '-36.1217431126412',
#   '6.51117411951536'],
#  ['WT_CTATTCTGAGCG',
#   'CTATTCTGAGCG',
#   '5',
#   'WT_CTATTCTGAGCG',
#   '-37.2323857000113',
#   '12.2904864681492'],
#  ['WT_AGCGCTTAAGAA',
#   'AGCGCTTAAGAA',
#   '5',
#   'WT_AGCGCTTAAGAA',
#   '-37.7088471845738',
#   '9.76766392169903'],
#  ['WT_GACCTTACGCTG',
#   'GACCTTACGCTG',
#   '5',
#   'WT_GACCTTACGCTG',
#   '-30.241649299739',
#   '7.71605453940428'],
#  ['WT_TACCCCCGCATT',
#   'TACCCCCGCATT',
#   '5',
#   'WT_TACCCCCGCATT',
#   '-36.5711217461185',
#   '13.418001877944'],
#  ['WT_TTATCGCGTCCT',
#   'TTATCGCGTCCT',
#   '5',
#   'WT_TTATCGCGTCCT',
#   '-36.4305648922497',
#   '12.0303780806824'],
#  ['WT_TTGAACTGTCCT',
#   'TTGAACTGTCCT',
#   '5',
#   'WT_TTGAACTGTCCT',
#   '-39.1375611183558',
#   '7.79502023513769'],
#  ['WT_GGCAAGGGTGCG',
#   'GGCAAGGGTGCG',
#   '5',
#   'WT_GGCAAGGGTGCG',
#   '-28.2923866945288',
#   '8.50363725273531'],
#  ['WT_CGAGCGCATAAT',
#   'CGAGCGCATAAT',
#   '5',
#   'WT_CGAGCGCATAAT',
#   '-33.0155412837985',
#   '11.0701152376147'],
#  ['WT_GCCTAGAGGAGG',
#   'GCCTAGAGGAGG',
#   '5',
#   'WT_GCCTAGAGGAGG',
#   '-37.62653338162',
#   '-3.30433955375524'],
#  ['WT_GCAGGGATCAGT',
#   'GCAGGGATCAGT',
#   '9',
#   'WT_GCAGGGATCAGT',
#   '-38.6881669820384',
#   '-2.61995631237866'],
#  ['WT_TCTCGTATGTCA',
#   'TCTCGTATGTCA',
#   '5',
#   'WT_TCTCGTATGTCA',
#   '-32.39711597668',
#   '6.96962586533151'],
#  ['WT_GCACCAGGACTC',
#   'GCACCAGGACTC',
#   '5',
#   'WT_GCACCAGGACTC',
#   '-31.4431717190247',
#   '10.5385965279205'],
#  ['WT_CCACATGTGATC',
#   'CCACATGTGATC',
#   '5',
#   'WT_CCACATGTGATC',
#   '-32.4840858561358',
#   '13.1620996128818'],
#  ['WT_AAGAACAGTCCA',
#   'AAGAACAGTCCA',
#   '5',
#   'WT_AAGAACAGTCCA',
#   '-36.9240979717562',
#   '4.07290218549791'],
#  ['WT_CAGACACCAGAA',
#   'CAGACACCAGAA',
#   '5',
#   'WT_CAGACACCAGAA',
#   '-36.6115883750857',
#   '11.7328300436874'],
#  ['WT_GGGTTGACGAGT',
#   'GGGTTGACGAGT',
#   '5',
#   'WT_GGGTTGACGAGT',
#   '-28.2611326898176',
#   '8.47241394285277'],
#  ['WT_TAGTCGACGGTT',
#   'TAGTCGACGGTT',
#   '5',
#   'WT_TAGTCGACGGTT',
#   '-33.6570714185422',
#   '8.22941693140762'],
#  ['WT_GATCAGTGTCTC',
#   'GATCAGTGTCTC',
#   '5',
#   'WT_GATCAGTGTCTC',
#   '-30.4807348627968',
#   '7.12387495201732'],
#  ['WT_TGTACGTAATTA',
#   'TGTACGTAATTA',
#   '9',
#   'WT_TGTACGTAATTA',
#   '-37.4045078345085',
#   '-3.84329080182879'],
#  ['WT_GCGATCTACGTA',
#   'GCGATCTACGTA',
#   '5',
#   'WT_GCGATCTACGTA',
#   '-28.7182938124003',
#   '7.50642277840241'],
#  ['WT_GTTTGCGAACGA',
#   'GTTTGCGAACGA',
#   '5',
#   'WT_GTTTGCGAACGA',
#   '-23.7749034624411',
#   '2.72905360055998'],
#  ['WT_TTTGAATTCTGC',
#   'TTTGAATTCTGC',
#   '5',
#   'WT_TTTGAATTCTGC',
#   '-31.9237765636472',
#   '8.01601064983649'],
#  ['WT_TAGGTAACCTAC',
#   'TAGGTAACCTAC',
#   '5',
#   'WT_TAGGTAACCTAC',
#   '-29.3871138947121',
#   '10.8111903352271'],
#  ['WT_TTTAGGGCGCTT',
#   'TTTAGGGCGCTT',
#   '5',
#   'WT_TTTAGGGCGCTT',
#   '-31.680900298752',
#   '12.7799559195173'],
#  ['WT_GTCACGCCCCAC',
#   'GTCACGCCCCAC',
#   '5',
#   'WT_GTCACGCCCCAC',
#   '-36.00898831285',
#   '10.7330796031972'],
#  ['WT_AATTGAAGCACA',
#   'AATTGAAGCACA',
#   '5',
#   'WT_AATTGAAGCACA',
#   '-29.7653786732195',
#   '4.73363146048655'],
#  ['WT_ACTACTTATTTC',
#   'ACTACTTATTTC',
#   '5',
#   'WT_ACTACTTATTTC',
#   '-38.2123030360543',
#   '1.33982439677263'],
#  ['WT_CGCGATGTTCAA',
#   'CGCGATGTTCAA',
#   '5',
#   'WT_CGCGATGTTCAA',
#   '-32.578434976412',
#   '7.54977698335658'],
#  ['WT_TGTACTCCGAGA',
#   'TGTACTCCGAGA',
#   '5',
#   'WT_TGTACTCCGAGA',
#   '-34.9845532903549',
#   '10.3541885711935'],
#  ['WT_GTGAAATTGGTT',
#   'GTGAAATTGGTT',
#   '5',
#   'WT_GTGAAATTGGTT',
#   '-32.4325476432547',
#   '8.52337486097226'],
#  ['WT_TATGTGCTTATC',
#   'TATGTGCTTATC',
#   '5',
#   'WT_TATGTGCTTATC',
#   '-30.7031874249822',
#   '5.99478114225818'],
#  ['WT_CCGGCACGCGAT',
#   'CCGGCACGCGAT',
#   '9',
#   'WT_CCGGCACGCGAT',
#   '-39.2909523767217',
#   '-2.96425167526623'],
#  ['WT_GATGTCCGTCTT',
#   'GATGTCCGTCTT',
#   '5',
#   'WT_GATGTCCGTCTT',
#   '-31.6749652962545',
#   '3.50125788070249'],
#  ['WT_ATTGTGCCCGTG',
#   'ATTGTGCCCGTG',
#   '5',
#   'WT_ATTGTGCCCGTG',
#   '-28.8173438806033',
#   '9.77504522470755'],
#  ['WT_TGTGTAAGTTTG',
#   'TGTGTAAGTTTG',
#   '5',
#   'WT_TGTGTAAGTTTG',
#   '-36.4334967516256',
#   '13.1328647999015'],
#  ['WT_TAACGCGAGCCT',
#   'TAACGCGAGCCT',
#   '5',
#   'WT_TAACGCGAGCCT',
#   '-35.1769986383106',
#   '0.279987024848867'],
#  ['WT_GGCACACATACG',
#   'GGCACACATACG',
#   '5',
#   'WT_GGCACACATACG',
#   '-29.8587642510008',
#   '6.95776322381426'],
#  ['WT_TCTGGAACACTA',
#   'TCTGGAACACTA',
#   '5',
#   'WT_TCTGGAACACTA',
#   '-33.5226238815133',
#   '4.65389995562964'],
#  ['WT_ACCCTTATTGGG',
#   'ACCCTTATTGGG',
#   '5',
#   'WT_ACCCTTATTGGG',
#   '-30.9512388791234',
#   '7.82730016377173'],
#  ['WT_AAACACCGGAAT',
#   'AAACACCGGAAT',
#   '10',
#   'WT_AAACACCGGAAT',
#   '-24.8931123402441',
#   '0.600222965731049'],
#  ['WT_GTGGGTAGCTCG',
#   'GTGGGTAGCTCG',
#   '5',
#   'WT_GTGGGTAGCTCG',
#   '-36.1074507556167',
#   '2.71879030353004'],
#  ['WT_AATGTCGCTTTN',
#   'AATGTCGCTTTN',
#   '5',
#   'WT_AATGTCGCTTTN',
#   '-30.6194997344124',
#   '0.266001584425384'],
#  ['WT_AACCCCTTACAT',
#   'AACCCCTTACAT',
#   '5',
#   'WT_AACCCCTTACAT',
#   '-33.9866443897494',
#   '5.80406672168084'],
#  ['WT_TTGAAGTTCTGG',
#   'TTGAAGTTCTGG',
#   '5',
#   'WT_TTGAAGTTCTGG',
#   '-36.2697675756605',
#   '8.11617412095076'],
#  ['WT_TACCTCTAAATA',
#   'TACCTCTAAATA',
#   '5',
#   'WT_TACCTCTAAATA',
#   '-29.3211848703164',
#   '0.0472989060103193'],
#  ['WT_AACTATCCCCCA',
#   'AACTATCCCCCA',
#   '5',
#   'WT_AACTATCCCCCA',
#   '-37.8610316389636',
#   '-2.46947955330414'],
#  ['WT_GCTCAATAACGC',
#   'GCTCAATAACGC',
#   '5',
#   'WT_GCTCAATAACGC',
#   '-26.8914842796297',
#   '3.90789078486309'],
#  ['WT_GACGTATGCAAG',
#   'GACGTATGCAAG',
#   '5',
#   'WT_GACGTATGCAAG',
#   '-32.4703403888931',
#   '5.27726474674226'],
#  ['WT_CTGAACATCTTT',
#   'CTGAACATCTTT',
#   '5',
#   'WT_CTGAACATCTTT',
#   '-38.5030483547092',
#   '-2.26099874773647'],
#  ['WT_TTCTGAGGTGAC',
#   'TTCTGAGGTGAC',
#   '10',
#   'WT_TTCTGAGGTGAC',
#   '-24.8313000739106',
#   '0.485703013702565'],
#  ['WT_CGCCAGCGCGGA',
#   'CGCCAGCGCGGA',
#   '5',
#   'WT_CGCCAGCGCGGA',
#   '-30.8001041149431',
#   '9.8150114060405'],
#  ['WT_TCAACAATAACC',
#   'TCAACAATAACC',
#   '5',
#   'WT_TCAACAATAACC',
#   '-40.5213505929647',
#   '5.69953964850463'],
#  ['WT_CAGCGGCAGGCT',
#   'CAGCGGCAGGCT',
#   '5',
#   'WT_CAGCGGCAGGCT',
#   '-28.4911108116761',
#   '5.01161990956341'],
#  ['WT_CGCGTTCCCTCC',
#   'CGCGTTCCCTCC',
#   '5',
#   'WT_CGCGTTCCCTCC',
#   '-39.9108656919436',
#   '4.82638727779861'],
#  ['WT_TCGGATACTCAA',
#   'TCGGATACTCAA',
#   '10',
#   'WT_TCGGATACTCAA',
#   '-22.2138684477387',
#   '-9.14576103764941'],
#  ['WT_TGTCCTCCAGAT',
#   'TGTCCTCCAGAT',
#   '5',
#   'WT_TGTCCTCCAGAT',
#   '-32.1451052458177',
#   '5.1871738348906'],
#  ['WT_TATTCACGATTT',
#   'TATTCACGATTT',
#   '5',
#   'WT_TATTCACGATTT',
#   '-30.5512643974582',
#   '1.97774181824079'],
#  ['WT_CGGGCGAGATCC',
#   'CGGGCGAGATCC',
#   '5',
#   'WT_CGGGCGAGATCC',
#   '-35.8261798389563',
#   '8.75107377887066'],
#  ['WT_GAGACCCGAAGG',
#   'GAGACCCGAAGG',
#   '5',
#   'WT_GAGACCCGAAGG',
#   '-31.7991992098022',
#   '8.2282515609709'],
#  ['WT_TTGGATGTTGCG',
#   'TTGGATGTTGCG',
#   '5',
#   'WT_TTGGATGTTGCG',
#   '-34.1116414139056',
#   '7.86151189453928'],
#  ['WT_ACATCGGTCGTT',
#   'ACATCGGTCGTT',
#   '5',
#   'WT_ACATCGGTCGTT',
#   '-35.3836502900035',
#   '8.99977326881423'],
#  ['WT_CGCCGGAGGCCA',
#   'CGCCGGAGGCCA',
#   '10',
#   'WT_CGCCGGAGGCCA',
#   '-24.078092143079',
#   '-0.252140362560813'],
#  ['WT_GTTAGTGCGTTG',
#   'GTTAGTGCGTTG',
#   '5',
#   'WT_GTTAGTGCGTTG',
#   '-27.7371285745726',
#   '3.88836829321228'],
#  ['WT_GGGTCGGTGGTC',
#   'GGGTCGGTGGTC',
#   '5',
#   'WT_GGGTCGGTGGTC',
#   '-30.4330727645723',
#   '8.81441629782109'],
#  ['WT_CCCTGACACTGC',
#   'CCCTGACACTGC',
#   '5',
#   'WT_CCCTGACACTGC',
#   '-30.4562116017099',
#   '4.2949685775316'],
#  ['WT_TGGTAGTTGCTG',
#   'TGGTAGTTGCTG',
#   '5',
#   'WT_TGGTAGTTGCTG',
#   '-34.8032028830228',
#   '9.81776888832702'],
#  ['WT_CTGGGAGAGTTG',
#   'CTGGGAGAGTTG',
#   '5',
#   'WT_CTGGGAGAGTTG',
#   '-41.13060021835',
#   '3.61725380300232'],
#  ['WT_CGTGAAGCTCTA',
#   'CGTGAAGCTCTA',
#   '5',
#   'WT_CGTGAAGCTCTA',
#   '-32.6815924973741',
#   '1.97152154276711'],
#  ['WT_TTCGCAGTGCGG',
#   'TTCGCAGTGCGG',
#   '5',
#   'WT_TTCGCAGTGCGG',
#   '-24.7091833724457',
#   '2.06904410485661'],
#  ['WT_CCGCACCCGAGG',
#   'CCGCACCCGAGG',
#   '5',
#   'WT_CCGCACCCGAGG',
#   '-30.0132862345491',
#   '5.69681402452866'],
#  ['WT_AGAGGAGTCACG',
#   'AGAGGAGTCACG',
#   '5',
#   'WT_AGAGGAGTCACG',
#   '-33.3297533435429',
#   '4.42084212361212'],
#  ['WT_CTTTCTAGGTCG',
#   'CTTTCTAGGTCG',
#   '5',
#   'WT_CTTTCTAGGTCG',
#   '-36.725668566418',
#   '8.76216663648507'],
#  ['WT_ATTTTTCGCACG',
#   'ATTTTTCGCACG',
#   '5',
#   'WT_ATTTTTCGCACG',
#   '-34.1617101290432',
#   '11.5878401247467'],
#  ['WT_TCGTTAGAGGCT',
#   'TCGTTAGAGGCT',
#   '5',
#   'WT_TCGTTAGAGGCT',
#   '-35.0919347854155',
#   '10.5492321497696'],
#  ['WT_ACGGGGCGATAA',
#   'ACGGGGCGATAA',
#   '10',
#   'WT_ACGGGGCGATAA',
#   '-15.6007650057823',
#   '-2.42861349121483'],
#  ['WT_TGTTAACGTTAC',
#   'TGTTAACGTTAC',
#   '5',
#   'WT_TGTTAACGTTAC',
#   '-28.5728480772053',
#   '5.20955418695789'],
#  ['WT_CATCATTAAGCT',
#   'CATCATTAAGCT',
#   '5',
#   'WT_CATCATTAAGCT',
#   '-29.1431900296289',
#   '-0.0850241225572232'],
#  ['WT_CAAGAGCTTTAT',
#   'CAAGAGCTTTAT',
#   '5',
#   'WT_CAAGAGCTTTAT',
#   '-30.9355538948827',
#   '8.81165391677745'],
#  ['WT_GCTTACAGTGGC',
#   'GCTTACAGTGGC',
#   '5',
#   'WT_GCTTACAGTGGC',
#   '-29.8643957838358',
#   '1.7336992822544'],
#  ['WT_TTGATAGGTTAA',
#   'TTGATAGGTTAA',
#   '5',
#   'WT_TTGATAGGTTAA',
#   '-31.9902910462721',
#   '9.0057450178847'],
#  ['WT_ATCACTCGTAAA',
#   'ATCACTCGTAAA',
#   '5',
#   'WT_ATCACTCGTAAA',
#   '-28.5408799648787',
#   '4.58334740223125'],
#  ['WT_TCCGCGTATTCA',
#   'TCCGCGTATTCA',
#   '5',
#   'WT_TCCGCGTATTCA',
#   '-37.9133022198457',
#   '-1.9256018236072'],
#  ['WT_CTTGGAAGAGCA',
#   'CTTGGAAGAGCA',
#   '5',
#   'WT_CTTGGAAGAGCA',
#   '-30.2767037077391',
#   '2.05590420784043'],
#  ['WT_CAATGTCGCTTT',
#   'CAATGTCGCTTT',
#   '5',
#   'WT_CAATGTCGCTTT',
#   '-30.7426674072295',
#   '0.377905120087996'],
#  ['WT_TAAATCTGGAAA',
#   'TAAATCTGGAAA',
#   '5',
#   'WT_TAAATCTGGAAA',
#   '-30.0021106560513',
#   '4.61248357393207'],
#  ['WT_AGCATTCCAGTA',
#   'AGCATTCCAGTA',
#   '10',
#   'WT_AGCATTCCAGTA',
#   '-24.072156561784',
#   '0.171642284513769'],
#  ['WT_GCAGTTGGAAAN',
#   'GCAGTTGGAAAN',
#   '5',
#   'WT_GCAGTTGGAAAN',
#   '-28.739150367124',
#   '5.63057951851418'],
#  ['WT_ATCAAGGCTATT',
#   'ATCAAGGCTATT',
#   '5',
#   'WT_ATCAAGGCTATT',
#   '-30.126015972254',
#   '-2.00837230362563'],
#  ['WT_ACAGCCCCCTAN',
#   'ACAGCCCCCTAN',
#   '5',
#   'WT_ACAGCCCCCTAN',
#   '-33.1021467296662',
#   '12.4362456333195'],
#  ['WT_GCCACAAACGAA',
#   'GCCACAAACGAA',
#   '5',
#   'WT_GCCACAAACGAA',
#   '-35.1842071278898',
#   '9.53298513097553'],
#  ['WT_GTCCTAATGTTC',
#   'GTCCTAATGTTC',
#   '5',
#   'WT_GTCCTAATGTTC',
#   '-31.5981678916888',
#   '3.94006932913329'],
#  ['WT_TAAGTTTTGTGA',
#   'TAAGTTTTGTGA',
#   '5',
#   'WT_TAAGTTTTGTGA',
#   '-33.5383958038357',
#   '8.9095462144722'],
#  ['WT_TTTGCGCTGATC',
#   'TTTGCGCTGATC',
#   '5',
#   'WT_TTTGCGCTGATC',
#   '-33.2627123081233',
#   '0.529282634223102'],
#  ['WT_TAGAACATAACN',
#   'TAGAACATAACN',
#   '5',
#   'WT_TAGAACATAACN',
#   '-31.9405217581446',
#   '9.52665464614894'],
#  ['WT_GATCGCAACGAA',
#   'GATCGCAACGAA',
#   '5',
#   'WT_GATCGCAACGAA',
#   '-34.1990054734504',
#   '10.411490352789'],
#  ['WT_CCGTCTAGAGAN',
#   'CCGTCTAGAGAN',
#   '5',
#   'WT_CCGTCTAGAGAN',
#   '-32.6940831109214',
#   '0.0658669757135284'],
#  ['WT_CACTCTCTAGGG',
#   'CACTCTCTAGGG',
#   '5',
#   'WT_CACTCTCTAGGG',
#   '-35.8445846109467',
#   '10.3522163227047'],
#  ['WT_TCCAAGTGAGTA',
#   'TCCAAGTGAGTA',
#   '5',
#   'WT_TCCAAGTGAGTA',
#   '-29.9765466299513',
#   '7.48369549388539'],
#  ['WT_CATGCTCCCCTC',
#   'CATGCTCCCCTC',
#   '10',
#   'WT_CATGCTCCCCTC',
#   '-24.0391218334645',
#   '-0.438044190183728'],
#  ['WT_ACTATCAGGGCA',
#   'ACTATCAGGGCA',
#   '9',
#   'WT_ACTATCAGGGCA',
#   '-38.1011216091707',
#   '-4.19117395369207'],
#  ['WT_AAAAGATTTCGA',
#   'AAAAGATTTCGA',
#   '5',
#   'WT_AAAAGATTTCGA',
#   '-30.2684143378263',
#   '8.00990622340072'],
#  ['GF_CCGTCCGTGGGN',
#   'CCGTCCGTGGGN',
#   '5',
#   'GF_CCGTCCGTGGGN',
#   '-8.63135352931372',
#   '24.2029716602343'],
#  ['GF_TATTTGACGGTC',
#   'TATTTGACGGTC',
#   '5',
#   'GF_TATTTGACGGTC',
#   '-38.7251002544704',
#   '4.29104261169468'],
#  ['GF_GCTGGGCCTGTN',
#   'GCTGGGCCTGTN',
#   '9',
#   'GF_GCTGGGCCTGTN',
#   '-41.6086439498836',
#   '-3.85150207404197'],
#  ['GF_TCTGCCAGTGAT',
#   'TCTGCCAGTGAT',
#   '10',
#   'GF_TCTGCCAGTGAT',
#   '-24.8827132842492',
#   '0.126997699760797'],
#  ['GF_TACTCATCAAAN',
#   'TACTCATCAAAN',
#   '5',
#   'GF_TACTCATCAAAN',
#   '-41.0724356736607',
#   '8.89457626107109'],
#  ['GF_CACATGCACTGT',
#   'CACATGCACTGT',
#   '10',
#   'GF_CACATGCACTGT',
#   '-23.4825133687458',
#   '-0.0912279437313779'],
#  ['WT_TCCGTATCGCTN',
#   'TCCGTATCGCTN',
#   '5',
#   'WT_TCCGTATCGCTN',
#   '-30.7072996196935',
#   '0.570029618484742'],
#  ['GF_TGCTGATTCCGN',
#   'TGCTGATTCCGN',
#   '10',
#   'GF_TGCTGATTCCGN',
#   '-24.5873594870261',
#   '-10.364931720971'],
#  ['GF_CGCAGCACGGGA',
#   'CGCAGCACGGGA',
#   '5',
#   'GF_CGCAGCACGGGA',
#   '-24.9593176126768',
#   '4.59113204620539'],
#  ['GF_TCCGCAACCCAN',
#   'TCCGCAACCCAN',
#   '10',
#   'GF_TCCGCAACCCAN',
#   '-22.8757808519517',
#   '-1.43957709576722'],
#  ['GF_CAGTTCTAATAC',
#   'CAGTTCTAATAC',
#   '10',
#   'GF_CAGTTCTAATAC',
#   '-23.4888984600702',
#   '0.600615977548207'],
#  ['GF_TGCTGAGGTTGC',
#   'TGCTGAGGTTGC',
#   '5',
#   'GF_TGCTGAGGTTGC',
#   '-28.2223994065824',
#   '-1.49338633044042'],
#  ['WT_GTCGTCGAGGTC',
#   'GTCGTCGAGGTC',
#   '10',
#   'WT_GTCGTCGAGGTC',
#   '-18.4948558997042',
#   '1.08076869179974'],
#  ['GF_CAATTCACACTN',
#   'CAATTCACACTN',
#   '10',
#   'GF_CAATTCACACTN',
#   '-20.7861149795317',
#   '-5.60502432954988'],
#  ['GF_CATTCTTCGTCA',
#   'CATTCTTCGTCA',
#   '10',
#   'GF_CATTCTTCGTCA',
#   '-24.5656204133356',
#   '-4.69981134200911'],
#  ['GF_TGCTGGCGTGGC',
#   'TGCTGGCGTGGC',
#   '10',
#   'GF_TGCTGGCGTGGC',
#   '-23.8967388152987',
#   '-6.75090966129606'],
#  ['GF_GATCTATTCCTG',
#   'GATCTATTCCTG',
#   '10',
#   'GF_GATCTATTCCTG',
#   '-24.249732500508',
#   '-5.36486755966438'],
#  ['GF_ACGACCAGAAAC',
#   'ACGACCAGAAAC',
#   '10',
#   'GF_ACGACCAGAAAC',
#   '-24.2870370354777',
#   '-6.71734457689734'],
#  ['GF_CTTTGTCCATTG',
#   'CTTTGTCCATTG',
#   '10',
#   'GF_CTTTGTCCATTG',
#   '-24.6654031937868',
#   '-6.47781861668996'],
#  ['GF_TCGCAATGTGTT',
#   'TCGCAATGTGTT',
#   '10',
#   'GF_TCGCAATGTGTT',
#   '-25.3716496137456',
#   '-9.2534577033504'],
#  ['GF_ATTACTTGAGTG',
#   'ATTACTTGAGTG',
#   '10',
#   'GF_ATTACTTGAGTG',
#   '-24.4982454615526',
#   '-6.2482176534495'],
#  ['GF_TTACGAGGTCAC',
#   'TTACGAGGTCAC',
#   '10',
#   'GF_TTACGAGGTCAC',
#   '-24.4401514823108',
#   '-6.33725060846698'],
#  ['GF_CCAGAAGCGAAN',
#   'CCAGAAGCGAAN',
#   '10',
#   'GF_CCAGAAGCGAAN',
#   '-25.1964260728952',
#   '-5.97192232972627'],
#  ['GF_CTAAGAGTATCC',
#   'CTAAGAGTATCC',
#   '10',
#   'GF_CTAAGAGTATCC',
#   '-20.0316927948635',
#   '-5.29682575798683'],
#  ['GF_TGGTTTCCGGGN',
#   'TGGTTTCCGGGN',
#   '10',
#   'GF_TGGTTTCCGGGN',
#   '-24.5603723877632',
#   '-6.42965293349548'],
#  ['GF_GGCAGCGTCTTT',
#   'GGCAGCGTCTTT',
#   '10',
#   'GF_GGCAGCGTCTTT',
#   '-23.1525418501417',
#   '-5.74706966969327'],
#  ['GF_AATAGCCGCAGG',
#   'AATAGCCGCAGG',
#   '10',
#   'GF_AATAGCCGCAGG',
#   '-24.0029539594584',
#   '-6.53852574784006'],
#  ['GF_TCAGGCACTGCT',
#   'TCAGGCACTGCT',
#   '10',
#   'GF_TCAGGCACTGCT',
#   '-22.4223172938586',
#   '-6.2383605703042'],
#  ['GF_TATCTCTCCAGC',
#   'TATCTCTCCAGC',
#   '10',
#   'GF_TATCTCTCCAGC',
#   '-15.5742914997706',
#   '-7.35814036457131'],
#  ['GF_AGAACGATACGC',
#   'AGAACGATACGC',
#   '10',
#   'GF_AGAACGATACGC',
#   '-18.814816390728',
#   '-5.43639977145847'],
#  ['GF_ACTATATCCTTC',
#   'ACTATATCCTTC',
#   '10',
#   'GF_ACTATATCCTTC',
#   '-24.2814484410388',
#   '-4.49218832679689'],
#  ['GF_CGACAGTTTTTT',
#   'CGACAGTTTTTT',
#   '10',
#   'GF_CGACAGTTTTTT',
#   '-19.5115735657178',
#   '-4.95415017535368'],
#  ['GF_GCCACGCTTGCA',
#   'GCCACGCTTGCA',
#   '10',
#   'GF_GCCACGCTTGCA',
#   '-23.7807297527889',
#   '-4.51239413981513'],
#  ['GF_CTCCCCTAAATC',
#   'CTCCCCTAAATC',
#   '10',
#   'GF_CTCCCCTAAATC',
#   '-24.3667929924366',
#   '-5.40093787056458'],
#  ['GF_CTATTAACTGCC',
#   'CTATTAACTGCC',
#   '10',
#   'GF_CTATTAACTGCC',
#   '-25.2895027917785',
#   '-5.55254988076954'],
#  ['GF_CCCAGACGTGCA',
#   'CCCAGACGTGCA',
#   '10',
#   'GF_CCCAGACGTGCA',
#   '-23.508937456297',
#   '-6.24923544129145'],
#  ['GF_CGGTCAGTCCGT',
#   'CGGTCAGTCCGT',
#   '10',
#   'GF_CGGTCAGTCCGT',
#   '-24.320689957438',
#   '-4.66893273619583'],
#  ['GF_GGATGGGTGGAG',
#   'GGATGGGTGGAG',
#   '10',
#   'GF_GGATGGGTGGAG',
#   '-24.18690437917',
#   '-6.60591969355128'],
#  ['GF_CTAAGTCTCAGA',
#   'CTAAGTCTCAGA',
#   '10',
#   'GF_CTAAGTCTCAGA',
#   '-22.0580862865989',
#   '-1.92462153252948'],
#  ['GF_ATGATTCGGGTC',
#   'ATGATTCGGGTC',
#   '10',
#   'GF_ATGATTCGGGTC',
#   '-24.1692702232449',
#   '-6.39088085516006'],
#  ['GF_AAACTACCGCTC',
#   'AAACTACCGCTC',
#   '10',
#   'GF_AAACTACCGCTC',
#   '-22.3850610205877',
#   '-6.16491497052125'],
#  ['GF_TTTCGTAACACT',
#   'TTTCGTAACACT',
#   '10',
#   'GF_TTTCGTAACACT',
#   '-24.6188333469883',
#   '-9.4977736333617'],
#  ['GF_GAAAGTTTGCAA',
#   'GAAAGTTTGCAA',
#   '10',
#   'GF_GAAAGTTTGCAA',
#   '-20.3346586238372',
#   '-5.60479594859276'],
#  ['GF_GTGCGCACAGGT',
#   'GTGCGCACAGGT',
#   '10',
#   'GF_GTGCGCACAGGT',
#   '-19.1636057105824',
#   '-7.72095791153732'],
#  ['GF_TTCGGTCGGCTN',
#   'TTCGGTCGGCTN',
#   '10',
#   'GF_TTCGGTCGGCTN',
#   '-22.6169070591773',
#   '-4.45751964829348'],
#  ['GF_GTAGAAGAGGAC',
#   'GTAGAAGAGGAC',
#   '10',
#   'GF_GTAGAAGAGGAC',
#   '-22.1549239786083',
#   '-5.34022495011981'],
#  ['GF_CCGAATGACCTT',
#   'CCGAATGACCTT',
#   '10',
#   'GF_CCGAATGACCTT',
#   '-23.1004376648206',
#   '-2.76136577193731'],
#  ['GF_TAGCTGCCCTCG',
#   'TAGCTGCCCTCG',
#   '10',
#   'GF_TAGCTGCCCTCG',
#   '-23.8766233603374',
#   '-3.93360535559468'],
#  ['GF_ATCGCGTTCGAG',
#   'ATCGCGTTCGAG',
#   '10',
#   'GF_ATCGCGTTCGAG',
#   '-24.3416104378225',
#   '-6.59692709304805'],
#  ['GF_TCCTCATCGTGG',
#   'TCCTCATCGTGG',
#   '10',
#   'GF_TCCTCATCGTGG',
#   '-21.1565212320592',
#   '-5.00193342091154'],
#  ['GF_TATGAGCAGCCG',
#   'TATGAGCAGCCG',
#   '10',
#   'GF_TATGAGCAGCCG',
#   '-18.9079219941739',
#   '-5.71475505855227'],
#  ['GF_CTCCGGCAAAAG',
#   'CTCCGGCAAAAG',
#   '5',
#   'GF_CTCCGGCAAAAG',
#   '-26.37941624181',
#   '-3.61153267595853'],
#  ['GF_ACCGACTAGGGG',
#   'ACCGACTAGGGG',
#   '10',
#   'GF_ACCGACTAGGGG',
#   '-22.3153221161446',
#   '-6.48116493575806'],
#  ['GF_CGGCTTAAGAGC',
#   'CGGCTTAAGAGC',
#   '10',
#   'GF_CGGCTTAAGAGC',
#   '-24.2722559016014',
#   '-2.15078011276463'],
#  ['GF_AAGTCTGCGCAC',
#   'AAGTCTGCGCAC',
#   '10',
#   'GF_AAGTCTGCGCAC',
#   '-19.8440029319516',
#   '-5.60140093330136'],
#  ['GF_ATGTTGGACCGA',
#   'ATGTTGGACCGA',
#   '10',
#   'GF_ATGTTGGACCGA',
#   '-23.2963287108508',
#   '-6.56081381042937'],
#  ['GF_TACAATCCATAC',
#   'TACAATCCATAC',
#   '10',
#   'GF_TACAATCCATAC',
#   '-23.4243096958432',
#   '-2.60396822185062'],
#  ['GF_TGCCCGTGGTGT',
#   'TGCCCGTGGTGT',
#   '10',
#   'GF_TGCCCGTGGTGT',
#   '-22.9719926886786',
#   '-6.508913460405'],
#  ['GF_CGTCACGCAGGC',
#   'CGTCACGCAGGC',
#   '10',
#   'GF_CGTCACGCAGGC',
#   '-24.7037819790003',
#   '-9.83316547014784'],
#  ['GF_CGTCAAAAGCTT',
#   'CGTCAAAAGCTT',
#   '10',
#   'GF_CGTCAAAAGCTT',
#   '-22.4485137741635',
#   '-1.90688517459717'],
#  ['GF_CCGAACGTGAGA',
#   'CCGAACGTGAGA',
#   '10',
#   'GF_CCGAACGTGAGA',
#   '-22.0453545939683',
#   '-6.38600329094356'],
#  ['GF_CTCGTTGCCGAG',
#   'CTCGTTGCCGAG',
#   '10',
#   'GF_CTCGTTGCCGAG',
#   '-23.4230310734592',
#   '-8.82531834004579'],
#  ['GF_TCAATGCATCCT',
#   'TCAATGCATCCT',
#   '5',
#   'GF_TCAATGCATCCT',
#   '-35.7659856565479',
#   '2.56363539780178'],
#  ['GF_TGTGCTACTATC',
#   'TGTGCTACTATC',
#   '10',
#   'GF_TGTGCTACTATC',
#   '-23.1953459262343',
#   '-1.84753217194324'],
#  ['GF_CAGGCAATGGCC',
#   'CAGGCAATGGCC',
#   '10',
#   'GF_CAGGCAATGGCC',
#   '-24.6393873203144',
#   '-0.324866998937388'],
#  ['WT_GGTCTATCCCGC',
#   'GGTCTATCCCGC',
#   '10',
#   'WT_GGTCTATCCCGC',
#   '-24.0714604162719',
#   '-6.56473444869951'],
#  ['WT_TACCGTCTCACA',
#   'TACCGTCTCACA',
#   '10',
#   'WT_TACCGTCTCACA',
#   '-19.1409053293534',
#   '-6.32141079398963'],
#  ['WT_CGGTTAGCACTA',
#   'CGGTTAGCACTA',
#   '10',
#   'WT_CGGTTAGCACTA',
#   '-18.1714018729002',
#   '-6.22818672452841'],
#  ['WT_CAAGTGTTGCAA',
#   'CAAGTGTTGCAA',
#   '10',
#   'WT_CAAGTGTTGCAA',
#   '-23.5695106647373',
#   '-6.95826944743999'],
#  ['WT_GCGACACGTGTA',
#   'GCGACACGTGTA',
#   '10',
#   'WT_GCGACACGTGTA',
#   '-23.7131012799134',
#   '-6.62441681388573'],
#  ['WT_CCGTCAACTAGT',
#   'CCGTCAACTAGT',
#   '10',
#   'WT_CCGTCAACTAGT',
#   '-24.14602944588',
#   '-6.55358147963207'],
#  ['WT_TTTTCACGTGTT',
#   'TTTTCACGTGTT',
#   '10',
#   'WT_TTTTCACGTGTT',
#   '-18.2781928152357',
#   '-5.98691081086143'],
#  ['WT_AGGATGCAAGGG',
#   'AGGATGCAAGGG',
#   '10',
#   'WT_AGGATGCAAGGG',
#   '-21.924124530154',
#   '-6.60766501275913'],
#  ['WT_GATGATTTCGAG',
#   'GATGATTTCGAG',
#   '10',
#   'WT_GATGATTTCGAG',
#   '-20.0145243591547',
#   '-9.08652693842737'],
#  ['WT_TAAGCCTCACCT',
#   'TAAGCCTCACCT',
#   '10',
#   'WT_TAAGCCTCACCT',
#   '-19.5834903464694',
#   '-6.3139955266879'],
#  ['WT_CGAGTCCTTTGC',
#   'CGAGTCCTTTGC',
#   '10',
#   'WT_CGAGTCCTTTGC',
#   '-18.1895587956739',
#   '-6.10262860677418'],
#  ['WT_GTCACACCCGGT',
#   'GTCACACCCGGT',
#   '10',
#   'WT_GTCACACCCGGT',
#   '-18.7485977658874',
#   '-7.66142832523447'],
#  ['WT_TTAAGTCGGAAG',
#   'TTAAGTCGGAAG',
#   '10',
#   'WT_TTAAGTCGGAAG',
#   '-19.1900472197331',
#   '-7.47686360595775'],
#  ['WT_CTCTCGCAGCCC',
#   'CTCTCGCAGCCC',
#   '10',
#   'WT_CTCTCGCAGCCC',
#   '-20.894996071598',
#   '-5.41960275218874'],
#  ['WT_AAGGCGATTTGA',
#   'AAGGCGATTTGA',
#   '10',
#   'WT_AAGGCGATTTGA',
#   '-24.9108058268506',
#   '-8.54869376152626'],
#  ['WT_CTCAGACGGGTG',
#   'CTCAGACGGGTG',
#   '10',
#   'WT_CTCAGACGGGTG',
#   '-18.8782137813791',
#   '-4.68415496331009'],
#  ['WT_CTTGGACAACCC',
#   'CTTGGACAACCC',
#   '10',
#   'WT_CTTGGACAACCC',
#   '-22.0284455075048',
#   '-6.31935151415479'],
#  ['WT_AAACCGGCCTAG',
#   'AAACCGGCCTAG',
#   '10',
#   'WT_AAACCGGCCTAG',
#   '-12.3518465993544',
#   '-5.93572713756185'],
#  ['WT_GCAGTGGAATCC',
#   'GCAGTGGAATCC',
#   '10',
#   'WT_GCAGTGGAATCC',
#   '-18.4390016829498',
#   '-5.70989399610729'],
#  ['WT_GCGAAGGAATCC',
#   'GCGAAGGAATCC',
#   '10',
#   'WT_GCGAAGGAATCC',
#   '-18.6451844706022',
#   '-5.33983420661872'],
#  ['WT_CCCGTTATATTA',
#   'CCCGTTATATTA',
#   '10',
#   'WT_CCCGTTATATTA',
#   '-24.1533515374708',
#   '-6.58083149532502'],
#  ['WT_TTCAACCCCTAG',
#   'TTCAACCCCTAG',
#   '10',
#   'WT_TTCAACCCCTAG',
#   '-19.3320118354756',
#   '-5.57853771201034'],
#  ['WT_GTGGCGAGGCAT',
#   'GTGGCGAGGCAT',
#   '10',
#   'WT_GTGGCGAGGCAT',
#   '-23.9220238383167',
#   '-6.70258772589889'],
#  ['WT_CGAACGGCTATC',
#   'CGAACGGCTATC',
#   '10',
#   'WT_CGAACGGCTATC',
#   '-21.4335711510395',
#   '-7.18826304838855'],
#  ['WT_AATCTTCCTGAC',
#   'AATCTTCCTGAC',
#   '10',
#   'WT_AATCTTCCTGAC',
#   '-19.8670422711473',
#   '-5.84031391170995'],
#  ['WT_ATCTACATTGAG',
#   'ATCTACATTGAG',
#   '10',
#   'WT_ATCTACATTGAG',
#   '-21.9637893639391',
#   '-9.87453344425202'],
#  ['WT_CGCTGCCGCTCA',
#   'CGCTGCCGCTCA',
#   '10',
#   'WT_CGCTGCCGCTCA',
#   '-19.1374161319267',
#   '-5.48345074972202'],
#  ['WT_AATCTTCAAATC',
#   'AATCTTCAAATC',
#   '10',
#   'WT_AATCTTCAAATC',
#   '-16.9457651587256',
#   '-3.86875698698686'],
#  ['WT_ACCGCAACAGAT',
#   'ACCGCAACAGAT',
#   '10',
#   'WT_ACCGCAACAGAT',
#   '-21.8709142694743',
#   '-3.64646163665957'],
#  ['WT_CGGGCAACTATA',
#   'CGGGCAACTATA',
#   '10',
#   'WT_CGGGCAACTATA',
#   '-20.7260916610178',
#   '-6.03016339784432'],
#  ['WT_TGTTATGTAAGA',
#   'TGTTATGTAAGA',
#   '10',
#   'WT_TGTTATGTAAGA',
#   '-19.0016522774429',
#   '-6.37589536516762'],
#  ['WT_GACCTTTAAATG',
#   'GACCTTTAAATG',
#   '10',
#   'WT_GACCTTTAAATG',
#   '-17.7901988038499',
#   '-4.74021315608426'],
#  ['WT_GGGGTGTAACGC',
#   'GGGGTGTAACGC',
#   '10',
#   'WT_GGGGTGTAACGC',
#   '-19.4059461983119',
#   '-6.0737859953988'],
#  ['GF_CCGTCTAAGGCC',
#   'CCGTCTAAGGCC',
#   '10',
#   'GF_CCGTCTAAGGCC',
#   '-22.49822366191',
#   '-6.26753011437498'],
#  ['GF_CCAGTGTATTTN',
#   'CCAGTGTATTTN',
#   '10',
#   'GF_CCAGTGTATTTN',
#   '-24.3913004980542',
#   '-4.5679520885585'],
#  ['GF_CACCTGCCCAAT',
#   'CACCTGCCCAAT',
#   '10',
#   'GF_CACCTGCCCAAT',
#   '-15.7680110420446',
#   '-7.47563112814075'],
#  ['GF_GTCCCACCTTCC',
#   'GTCCCACCTTCC',
#   '10',
#   'GF_GTCCCACCTTCC',
#   '-25.1500956642119',
#   '-4.90150777534606'],
#  ['GF_GAACCACAAACN',
#   'GAACCACAAACN',
#   '10',
#   'GF_GAACCACAAACN',
#   '-23.2473053481655',
#   '-4.80833712484443'],
#  ['GF_TCGAATGAAGGG',
#   'TCGAATGAAGGG',
#   '10',
#   'GF_TCGAATGAAGGG',
#   '-18.9710164239702',
#   '-7.93820980953053'],
#  ['WT_GGTGCCTTCGCT',
#   'GGTGCCTTCGCT',
#   '10',
#   'WT_GGTGCCTTCGCT',
#   '-18.6683613069962',
#   '-3.54816453600152'],
#  ['WT_AAAGAATTAAGC',
#   'AAAGAATTAAGC',
#   '10',
#   'WT_AAAGAATTAAGC',
#   '-19.634501567363',
#   '-9.20850280839059'],
#  ['WT_AATCAAGCTCCT',
#   'AATCAAGCTCCT',
#   '10',
#   'WT_AATCAAGCTCCT',
#   '-23.2218336311021',
#   '-4.74146898724754'],
#  ['WT_CGGCTGTCATAG',
#   'CGGCTGTCATAG',
#   '10',
#   'WT_CGGCTGTCATAG',
#   '-21.4252833812445',
#   '-7.61886802274104'],
#  ['GF_GGAGTCCTTGTN',
#   'GGAGTCCTTGTN',
#   '10',
#   'GF_GGAGTCCTTGTN',
#   '-17.291459646125',
#   '-11.3179617016566'],
#  ['GF_CACTCAAGCGCG',
#   'CACTCAAGCGCG',
#   '10',
#   'GF_CACTCAAGCGCG',
#   '-17.8499160904427',
#   '-9.38726921510459'],
#  ['GF_CATTTCAAAAGG',
#   'CATTTCAAAAGG',
#   '10',
#   'GF_CATTTCAAAAGG',
#   '-20.5275106061091',
#   '-0.215001015324768'],
#  ['GF_CCTGGGTAGGCA',
#   'CCTGGGTAGGCA',
#   '10',
#   'GF_CCTGGGTAGGCA',
#   '-18.055052188613',
#   '-5.11589239011937'],
#  ['GF_CGTAGTACAACC',
#   'CGTAGTACAACC',
#   '10',
#   'GF_CGTAGTACAACC',
#   '-24.8077367507489',
#   '-10.310697218937'],
#  ['GF_AGCCTCACTGCA',
#   'AGCCTCACTGCA',
#   '10',
#   'GF_AGCCTCACTGCA',
#   '-16.7705201578114',
#   '-11.240289945165'],
#  ['GF_GTAGTAGCCTAN',
#   'GTAGTAGCCTAN',
#   '10',
#   'GF_GTAGTAGCCTAN',
#   '-21.2808757049094',
#   '-9.66213767481096'],
#  ['GF_TTGGTATTTTGA',
#   'TTGGTATTTTGA',
#   '0',
#   'GF_TTGGTATTTTGA',
#   '-13.0949563417158',
#   '-11.288220365786'],
#  ['GF_CGGGTATTGGAG',
#   'CGGGTATTGGAG',
#   '10',
#   'GF_CGGGTATTGGAG',
#   '-22.2221403147005',
#   '-2.89106857896858'],
#  ['GF_GCAACACCGCCN',
#   'GCAACACCGCCN',
#   '10',
#   'GF_GCAACACCGCCN',
#   '-20.5365328756824',
#   '-1.01566297712925'],
#  ['GF_GTACCTCGCTCG',
#   'GTACCTCGCTCG',
#   '10',
#   'GF_GTACCTCGCTCG',
#   '-15.3255391224446',
#   '-1.8720798071806'],
#  ['GF_CGAGGTGGGTGG',
#   'CGAGGTGGGTGG',
#   '10',
#   'GF_CGAGGTGGGTGG',
#   '-15.8704293754345',
#   '-7.69844433893773'],
#  ['GF_TTGGACCCTGAA',
#   'TTGGACCCTGAA',
#   '10',
#   'GF_TTGGACCCTGAA',
#   '-17.0099142070549',
#   '-7.0853950337565'],
#  ['GF_AGTATTTGTGTA',
#   'AGTATTTGTGTA',
#   '10',
#   'GF_AGTATTTGTGTA',
#   '-16.0124361880651',
#   '-3.31493448232558'],
#  ['GF_CAAATTACGTCG',
#   'CAAATTACGTCG',
#   '10',
#   'GF_CAAATTACGTCG',
#   '-24.2493754770367',
#   '-1.5419911818059'],
#  ['GF_TCTTTAGCGTCT',
#   'TCTTTAGCGTCT',
#   '10',
#   'GF_TCTTTAGCGTCT',
#   '-24.8812614510773',
#   '-1.16861594110557'],
#  ['GF_CCGGCCCAATGA',
#   'CCGGCCCAATGA',
#   '10',
#   'GF_CCGGCCCAATGA',
#   '-21.1017239735198',
#   '-1.83568296282224'],
#  ['WT_CTAGCCGCATTG',
#   'CTAGCCGCATTG',
#   '10',
#   'WT_CTAGCCGCATTG',
#   '-15.8136393069309',
#   '-7.23911946118788'],
#  ['WT_GCGTAGTGGAAT',
#   'GCGTAGTGGAAT',
#   '10',
#   'WT_GCGTAGTGGAAT',
#   '-13.0237622533013',
#   '-6.92394082367851'],
#  ['WT_CCTGTGGTAGCG',
#   'CCTGTGGTAGCG',
#   '10',
#   'WT_CCTGTGGTAGCG',
#   '-19.9202574326672',
#   '-9.79469826961845'],
#  ['WT_TATGGCCTGAGA',
#   'TATGGCCTGAGA',
#   '10',
#   'WT_TATGGCCTGAGA',
#   '-15.2216269073432',
#   '-8.7872949929668'],
#  ['WT_GACATAGTCCGG',
#   'GACATAGTCCGG',
#   '5',
#   'WT_GACATAGTCCGG',
#   '-26.0186167652435',
#   '6.22850384256879'],
#  ['GF_TGTCAGCATTCC',
#   'TGTCAGCATTCC',
#   '0',
#   'GF_TGTCAGCATTCC',
#   '-4.28618554328799',
#   '-22.5518105176437'],
#  ['GF_AGGTAATTTAAT',
#   'AGGTAATTTAAT',
#   '0',
#   'GF_AGGTAATTTAAT',
#   '-5.63881551707463',
#   '-24.4031015987075'],
#  ['GF_ACGTTACGGAGT',
#   'ACGTTACGGAGT',
#   '0',
#   'GF_ACGTTACGGAGT',
#   '-5.25276939087017',
#   '-23.3526217187304'],
#  ['GF_TGTTCGTCGGGC',
#   'TGTTCGTCGGGC',
#   '0',
#   'GF_TGTTCGTCGGGC',
#   '-5.34221799897576',
#   '-22.1221040382483'],
#  ['GF_TAGGGGGCTTTT',
#   'TAGGGGGCTTTT',
#   '0',
#   'GF_TAGGGGGCTTTT',
#   '-5.43032409194681',
#   '-17.8815609725861'],
#  ['GF_AGAATCATCGAG',
#   'AGAATCATCGAG',
#   '0',
#   'GF_AGAATCATCGAG',
#   '-5.92746594576894',
#   '-15.7937429185714'],
#  ['GF_TCGGCCGAAGGC',
#   'TCGGCCGAAGGC',
#   '0',
#   'GF_TCGGCCGAAGGC',
#   '-7.17752455291516',
#   '-18.7650479803382'],
#  ['GF_TCGGACTGCCGC',
#   'TCGGACTGCCGC',
#   '10',
#   'GF_TCGGACTGCCGC',
#   '-17.3347671323492',
#   '1.04282236050027'],
#  ['WT_AATAACCTGTAG',
#   'AATAACCTGTAG',
#   '0',
#   'WT_AATAACCTGTAG',
#   '-5.28062723858588',
#   '-20.0145391735652'],
#  ['GF_TTAAAAAATTTT',
#   'TTAAAAAATTTT',
#   '10',
#   'GF_TTAAAAAATTTT',
#   '-17.093051656262',
#   '-6.99856278409575'],
#  ['GF_ACGTCGGAGGGC',
#   'ACGTCGGAGGGC',
#   '10',
#   'GF_ACGTCGGAGGGC',
#   '-16.8823364340403',
#   '-4.13462103494383'],
#  ['WT_CCTTAAAGCCCA',
#   'CCTTAAAGCCCA',
#   '0',
#   'WT_CCTTAAAGCCCA',
#   '-11.6192541286012',
#   '-8.4978545782086'],
#  ['WT_TTAGTAGGTCGA',
#   'TTAGTAGGTCGA',
#   '10',
#   'WT_TTAGTAGGTCGA',
#   '-16.8591818220782',
#   '-8.43999481924335'],
#  ['GF_ATTGGTTGATTT',
#   'ATTGGTTGATTT',
#   '0',
#   'GF_ATTGGTTGATTT',
#   '-21.5850907527618',
#   '-25.8749597419898'],
#  ['GF_TGGCCTGAATCG',
#   'TGGCCTGAATCG',
#   '0',
#   'GF_TGGCCTGAATCG',
#   '-12.0558612617124',
#   '-29.8127938237501'],
#  ['GF_CATATAGCTGGG',
#   'CATATAGCTGGG',
#   '0',
#   'GF_CATATAGCTGGG',
#   '-15.1427537113',
#   '-28.7493722891708'],
#  ['GF_GCCTACCTCCCN',
#   'GCCTACCTCCCN',
#   '0',
#   'GF_GCCTACCTCCCN',
#   '-17.1325913003912',
#   '-27.08314363267'],
#  ['GF_AGTTCTCCATGC',
#   'AGTTCTCCATGC',
#   '0',
#   'GF_AGTTCTCCATGC',
#   '-11.4041922530743',
#   '-26.8038603762521'],
#  ['GF_GCCACAGATCAA',
#   'GCCACAGATCAA',
#   '0',
#   'GF_GCCACAGATCAA',
#   '-21.0303465167352',
#   '-25.8829537340023'],
#  ['GF_AGAATGAGCTAT',
#   'AGAATGAGCTAT',
#   '0',
#   'GF_AGAATGAGCTAT',
#   '-5.98186202857251',
#   '-28.0548804051132'],
#  ['GF_TGAAGCCAGGAA',
#   'TGAAGCCAGGAA',
#   '0',
#   'GF_TGAAGCCAGGAA',
#   '-7.80871548614105',
#   '-18.6684991058373'],
#  ['GF_CGAACACCCAGG',
#   'CGAACACCCAGG',
#   '10',
#   'GF_CGAACACCCAGG',
#   '-17.2078397823228',
#   '-9.61580630945511'],
#  ['GF_GCCCATCATTTN',
#   'GCCCATCATTTN',
#   '0',
#   'GF_GCCCATCATTTN',
#   '-19.7618850270682',
#   '-29.5350741627638'],
#  ['GF_GTTTGACAGGCN',
#   'GTTTGACAGGCN',
#   '0',
#   'GF_GTTTGACAGGCN',
#   '-12.3760075969819',
#   '-29.5414927492149'],
#  ['GF_CCAATGACCATC',
#   'CCAATGACCATC',
#   '10',
#   'GF_CCAATGACCATC',
#   '-20.1787966553016',
#   '-2.33471909753032'],
#  ['GF_ATTGTATAGACN',
#   'ATTGTATAGACN',
#   '0',
#   'GF_ATTGTATAGACN',
#   '-21.30201612589',
#   '-22.6310485523299'],
#  ['GF_GCTCCGCTTACC',
#   'GCTCCGCTTACC',
#   '0',
#   'GF_GCTCCGCTTACC',
#   '-21.7673894041365',
#   '-27.0494192494509'],
#  ['GF_CGGCATTGGCAG',
#   'CGGCATTGGCAG',
#   '0',
#   'GF_CGGCATTGGCAG',
#   '-13.4354204070043',
#   '-31.0955127699238'],
#  ['GF_AGTCACCATCGG',
#   'AGTCACCATCGG',
#   '0',
#   'GF_AGTCACCATCGG',
#   '-9.99747584889892',
#   '-12.2917852650103'],
#  ['GF_CCTTTCCATTAG',
#   'CCTTTCCATTAG',
#   '0',
#   'GF_CCTTTCCATTAG',
#   '-14.0350396868421',
#   '-30.6325151762164'],
#  ['GF_GAACATGAGATT',
#   'GAACATGAGATT',
#   '10',
#   'GF_GAACATGAGATT',
#   '-15.1677719750365',
#   '-8.13407670357038'],
#  ['GF_CGACTTCAAGTG',
#   'CGACTTCAAGTG',
#   '0',
#   'GF_CGACTTCAAGTG',
#   '-19.8410992472417',
#   '-27.7700440183555'],
#  ['GF_ATAGTTCTTCAG',
#   'ATAGTTCTTCAG',
#   '0',
#   'GF_ATAGTTCTTCAG',
#   '-2.39825243639097',
#   '-28.1657867520134'],
#  ['GF_TCTCAGTGAGTG',
#   'TCTCAGTGAGTG',
#   '0',
#   'GF_TCTCAGTGAGTG',
#   '-15.6038527957047',
#   '-22.4406014327469'],
#  ['GF_CAAACTGGGGCC',
#   'CAAACTGGGGCC',
#   '0',
#   'GF_CAAACTGGGGCC',
#   '-20.7382977983878',
#   '-20.2003221076556'],
#  ['GF_AGTTTCACTAAN',
#   'AGTTTCACTAAN',
#   '0',
#   'GF_AGTTTCACTAAN',
#   '-22.2605228308898',
#   '-20.099879467577'],
#  ['GF_CCTTTCAAGAAN',
#   'CCTTTCAAGAAN',
#   '0',
#   'GF_CCTTTCAAGAAN',
#   '-25.679417581597',
#   '-18.6932760891094'],
#  ['GF_CATGATCCTTGC',
#   'CATGATCCTTGC',
#   '0',
#   'GF_CATGATCCTTGC',
#   '-9.3336952735233',
#   '-14.9227902893952'],
#  ['GF_GAGTTAAAGGTN',
#   'GAGTTAAAGGTN',
#   '0',
#   'GF_GAGTTAAAGGTN',
#   '-3.20689129315655',
#   '-25.60414634797'],
#  ['GF_TGGACGCTTTCG',
#   'TGGACGCTTTCG',
#   '0',
#   'GF_TGGACGCTTTCG',
#   '-22.6194857118664',
#   '-26.1771856115198'],
#  ['GF_CTCGGTTAAGTG',
#   'CTCGGTTAAGTG',
#   '0',
#   'GF_CTCGGTTAAGTG',
#   '-20.6124104618342',
#   '-12.6028125769114'],
#  ['GF_AAATTCCGGAAN',
#   'AAATTCCGGAAN',
#   '10',
#   'GF_AAATTCCGGAAN',
#   '-16.7717385743849',
#   '-9.66166601935716'],
#  ['GF_TTAACTGGAGCN',
#   'TTAACTGGAGCN',
#   '0',
#   'GF_TTAACTGGAGCN',
#   '-10.7061575283913',
#   '-25.3642297186355'],
#  ['GF_ATAGTAGGGATG',
#   'ATAGTAGGGATG',
#   '0',
#   'GF_ATAGTAGGGATG',
#   '-23.5225261922357',
#   '-26.026457951'],
#  ['GF_TGGGAGTCCTTG',
#   'TGGGAGTCCTTG',
#   '0',
#   'GF_TGGGAGTCCTTG',
#   '-21.4484125285219',
#   '-25.404815683072'],
#  ['GF_TAGGTATCGTAC',
#   'TAGGTATCGTAC',
#   '9',
#   'GF_TAGGTATCGTAC',
#   '-31.9547024203804',
#   '-16.9663957728297'],
#  ['GF_CTCGGAACCGAC',
#   'CTCGGAACCGAC',
#   '10',
#   'GF_CTCGGAACCGAC',
#   '-17.815405932707',
#   '-9.73041266980703'],
#  ['GF_GTTCACCCGAAC',
#   'GTTCACCCGAAC',
#   '0',
#   'GF_GTTCACCCGAAC',
#   '-21.4776213113216',
#   '-22.3308784419161'],
#  ['GF_GCGCATTCAGAG',
#   'GCGCATTCAGAG',
#   '0',
#   'GF_GCGCATTCAGAG',
#   '-11.7768917861896',
#   '-29.5837312633831'],
#  ['GF_TGGTCTAATCTG',
#   'TGGTCTAATCTG',
#   '0',
#   'GF_TGGTCTAATCTG',
#   '-9.97044239010851',
#   '-12.21704079708'],
#  ['GF_TCAACGTCGGCA',
#   'TCAACGTCGGCA',
#   '0',
#   'GF_TCAACGTCGGCA',
#   '-24.2054872598651',
#   '-19.4906966233272'],
#  ['GF_TGGTTTTTCGGG',
#   'TGGTTTTTCGGG',
#   '0',
#   'GF_TGGTTTTTCGGG',
#   '-17.5427787388242',
#   '-21.2991727515397'],
#  ['GF_ACGGATAGAAAN',
#   'ACGGATAGAAAN',
#   '0',
#   'GF_ACGGATAGAAAN',
#   '-12.3357250500963',
#   '-21.5432252895112'],
#  ['GF_GGCGCTCCTATN',
#   'GGCGCTCCTATN',
#   '0',
#   'GF_GGCGCTCCTATN',
#   '-19.8953387213352',
#   '-24.0773366207066'],
#  ['GF_GATCAGTTTCCN',
#   'GATCAGTTTCCN',
#   '0',
#   'GF_GATCAGTTTCCN',
#   '-3.7638280867713',
#   '-22.7148571855986'],
#  ['GF_ACTCCTTTTCAN',
#   'ACTCCTTTTCAN',
#   '0',
#   'GF_ACTCCTTTTCAN',
#   '-11.4717452190068',
#   '-20.9122582473455'],
#  ['GF_GTTCAGTGAGGT',
#   'GTTCAGTGAGGT',
#   '0',
#   'GF_GTTCAGTGAGGT',
#   '-4.50766036842407',
#   '-25.3404434088538'],
#  ['GF_GTATTCTCATCN',
#   'GTATTCTCATCN',
#   '11',
#   'GF_GTATTCTCATCN',
#   '-11.6998269735314',
#   '-23.5142073115817'],
#  ['GF_CTCCAATTCCAN',
#   'CTCCAATTCCAN',
#   '0',
#   'GF_CTCCAATTCCAN',
#   '-25.3725207164682',
#   '-23.5279740030039'],
#  ['GF_GGCCGGTTTTAA',
#   'GGCCGGTTTTAA',
#   '0',
#   'GF_GGCCGGTTTTAA',
#   '-19.0566776867047',
#   '-18.301794268898'],
#  ['GF_GCTGGTTAGTTT',
#   'GCTGGTTAGTTT',
#   '9',
#   'GF_GCTGGTTAGTTT',
#   '-30.6907841509499',
#   '-17.8845842774887'],
#  ['GF_CTCGAGTATCCN',
#   'CTCGAGTATCCN',
#   '0',
#   'GF_CTCGAGTATCCN',
#   '-15.6165445657632',
#   '-27.4260217652095'],
#  ['GF_GTCACGCCGCCN',
#   'GTCACGCCGCCN',
#   '0',
#   'GF_GTCACGCCGCCN',
#   '-16.417459163008',
#   '-22.4136753908815'],
#  ['GF_GGTCCACCCGAN',
#   'GGTCCACCCGAN',
#   '0',
#   'GF_GGTCCACCCGAN',
#   '-24.2053520640863',
#   '-17.238422079283'],
#  ['GF_CTCAGCTGGCCN',
#   'CTCAGCTGGCCN',
#   '0',
#   'GF_CTCAGCTGGCCN',
#   '-9.3730842717392',
#   '-11.3687512098705'],
#  ['GF_AAAGTTAAGCTG',
#   'AAAGTTAAGCTG',
#   '0',
#   'GF_AAAGTTAAGCTG',
#   '-25.637226241267',
#   '-21.9276687520551'],
#  ['GF_CTTACCCCTTCN',
#   'CTTACCCCTTCN',
#   '0',
#   'GF_CTTACCCCTTCN',
#   '-12.9203159047603',
#   '-13.8822915191723'],
#  ['GF_CATTTATTCTTC',
#   'CATTTATTCTTC',
#   '0',
#   'GF_CATTTATTCTTC',
#   '-25.2941764459762',
#   '-22.052027351086'],
#  ['GF_AGAACATAATCC',
#   'AGAACATAATCC',
#   '0',
#   'GF_AGAACATAATCC',
#   '-20.8878259344502',
#   '-29.2323394096422'],
#  ['GF_TCCAGCCAGAGN',
#   'TCCAGCCAGAGN',
#   '0',
#   'GF_TCCAGCCAGAGN',
#   '-13.3671391990451',
#   '-16.3631459726305'],
#  ['GF_ATTCCTTGTCTN',
#   'ATTCCTTGTCTN',
#   '0',
#   'GF_ATTCCTTGTCTN',
#   '-7.69559841983301',
#   '-14.9080626135827'],
#  ['GF_GGGGATCTTTCT',
#   'GGGGATCTTTCT',
#   '10',
#   'GF_GGGGATCTTTCT',
#   '-22.3191338177659',
#   '-2.72234537063692'],
#  ['GF_ACAGCTCCCCCN',
#   'ACAGCTCCCCCN',
#   '0',
#   'GF_ACAGCTCCCCCN',
#   '-14.0127076142872',
#   '-27.6351413730968'],
#  ['GF_GTCCTAAAGGAT',
#   'GTCCTAAAGGAT',
#   '0',
#   'GF_GTCCTAAAGGAT',
#   '-8.39374752071559',
#   '-22.4175000655687'],
#  ['GF_AAGAGGCGCTTT',
#   'AAGAGGCGCTTT',
#   '0',
#   'GF_AAGAGGCGCTTT',
#   '-11.5699066634217',
#   '-25.2832502088563'],
#  ['GF_CGCGCCGACTCN',
#   'CGCGCCGACTCN',
#   '0',
#   'GF_CGCGCCGACTCN',
#   '-14.0151084951282',
#   '-30.4331883291865'],
#  ['GF_CGGAGGTCGGAC',
#   'CGGAGGTCGGAC',
#   '10',
#   'GF_CGGAGGTCGGAC',
#   '-16.2559549815138',
#   '-8.78264722106663'],
#  ['GF_GTCAAAATTATG',
#   'GTCAAAATTATG',
#   '0',
#   'GF_GTCAAAATTATG',
#   '-11.1873976271397',
#   '-25.316310538402'],
#  ['GF_CAGCAGAACGCT',
#   'CAGCAGAACGCT',
#   '0',
#   'GF_CAGCAGAACGCT',
#   '-14.4970689044319',
#   '-22.4580106308042'],
#  ['GF_GCTAGCATAGCT',
#   'GCTAGCATAGCT',
#   '0',
#   'GF_GCTAGCATAGCT',
#   '-20.3091065007311',
#   '-28.3744394966979'],
#  ['GF_AAGCGAGATTTN',
#   'AAGCGAGATTTN',
#   '0',
#   'GF_AAGCGAGATTTN',
#   '-8.69216756262867',
#   '-25.8765235519403'],
#  ['GF_TCGTCACGAGAN',
#   'TCGTCACGAGAN',
#   '0',
#   'GF_TCGTCACGAGAN',
#   '-22.381944655918',
#   '-22.3587844142072'],
#  ['GF_GTCCAGCTGAAA',
#   'GTCCAGCTGAAA',
#   '0',
#   'GF_GTCCAGCTGAAA',
#   '-13.0766043854965',
#   '-29.4069940017011'],
#  ['GF_TTCAAGTTGCAG',
#   'TTCAAGTTGCAG',
#   '10',
#   'GF_TTCAAGTTGCAG',
#   '-17.401633880739',
#   '-8.95878525700514'],
#  ['GF_CTAAGGGAGATT',
#   'CTAAGGGAGATT',
#   '10',
# ...
#   '1',
#   'GF_AGTCTAAACTCG',
#   '-0.697057292721031',
#   '4.97062030572566'],
#  ['WT_GTATCAGGAGGT',
#   'GTATCAGGAGGT',
#   '1',
#   'WT_GTATCAGGAGGT',
#   '-1.13018864833024',
#   '4.54424853163515'],
#  ['WT_GCCCAGCACTTT',
#   'GCCCAGCACTTT',
#   '1',
#   'WT_GCCCAGCACTTT',
#   '-7.18477140938842',
#   '13.9295580608422'],
#  ['WT_GTATCACTCATT',
#   'GTATCACTCATT',
#   '1',
#   'WT_GTATCACTCATT',
#   '3.84260241164414',
#   '-2.00405170397691'],
#  ['WT_CGAGTCCCTGTN',
#   'CGAGTCCCTGTN',
#   '1',
#   'WT_CGAGTCCCTGTN',
#   '-9.28998886532683',
#   '21.2087988937298'],
#  ['WT_CAGGACTGTTGA',
#   'CAGGACTGTTGA',
#   '1',
#   'WT_CAGGACTGTTGA',
#   '-9.73626899349707',
#   '11.9731865270167'],
#  ['WT_CTCACTATTGCN',
#   'CTCACTATTGCN',
#   '1',
#   'WT_CTCACTATTGCN',
#   '-8.19729791360741',
#   '6.45849090007626'],
#  ['WT_ACATAACTTCGC',
#   'ACATAACTTCGC',
#   '1',
#   'WT_ACATAACTTCGC',
#   '-7.03229595541953',
#   '21.1498174543973'],
#  ['WT_CATGTATTTCCT',
#   'CATGTATTTCCT',
#   '1',
#   'WT_CATGTATTTCCT',
#   '4.17499965325936',
#   '-7.90636944558803'],
#  ['WT_GTGCTTTGCAAC',
#   'GTGCTTTGCAAC',
#   '1',
#   'WT_GTGCTTTGCAAC',
#   '-2.73345319131457',
#   '6.37066966360943'],
#  ['WT_GTGCAGTTTTAN',
#   'GTGCAGTTTTAN',
#   '1',
#   'WT_GTGCAGTTTTAN',
#   '-7.09846571326642',
#   '7.11481963118729'],
#  ['WT_TCTCGCGTGATG',
#   'TCTCGCGTGATG',
#   '1',
#   'WT_TCTCGCGTGATG',
#   '-7.39231814112235',
#   '22.2586416796239'],
#  ['WT_AGATAAGCCGCA',
#   'AGATAAGCCGCA',
#   '3',
#   'WT_AGATAAGCCGCA',
#   '1.69778493648225',
#   '4.33467710443191'],
#  ['WT_AGGAATCTGCCT',
#   'AGGAATCTGCCT',
#   '1',
#   'WT_AGGAATCTGCCT',
#   '-7.47907489243328',
#   '7.43599955720174'],
#  ['WT_TTGGGACCTTTA',
#   'TTGGGACCTTTA',
#   '1',
#   'WT_TTGGGACCTTTA',
#   '-9.24737556792081',
#   '3.32462462227353'],
#  ['WT_GACAGATGGCCC',
#   'GACAGATGGCCC',
#   '1',
#   'WT_GACAGATGGCCC',
#   '-14.9304282242598',
#   '-3.3411832450284'],
#  ['WT_CTTCTTAACCAG',
#   'CTTCTTAACCAG',
#   '1',
#   'WT_CTTCTTAACCAG',
#   '3.22599239000684',
#   '15.4968251585947'],
#  ['WT_CAAGCGCACTCT',
#   'CAAGCGCACTCT',
#   '1',
#   'WT_CAAGCGCACTCT',
#   '-4.7117303713175',
#   '12.9976067848852'],
#  ['WT_GAAACCTTGCAG',
#   'GAAACCTTGCAG',
#   '1',
#   'WT_GAAACCTTGCAG',
#   '-5.70398525531426',
#   '10.3447019794987'],
#  ['WT_ACCAGAGGCCAG',
#   'ACCAGAGGCCAG',
#   '1',
#   'WT_ACCAGAGGCCAG',
#   '-8.69264667379945',
#   '10.333063045831'],
#  ['WT_GGACCCGGGACN',
#   'GGACCCGGGACN',
#   '3',
#   'WT_GGACCCGGGACN',
#   '6.89258878838672',
#   '-6.59694167480472'],
#  ['WT_CAGCCTGAGTCA',
#   'CAGCCTGAGTCA',
#   '1',
#   'WT_CAGCCTGAGTCA',
#   '-8.5876045779686',
#   '4.25963974084502'],
#  ['WT_GGAGAAGGGGGA',
#   'GGAGAAGGGGGA',
#   '1',
#   'WT_GGAGAAGGGGGA',
#   '-8.82082084733544',
#   '16.3283335940106'],
#  ['WT_TAGTTCCATGTG',
#   'TAGTTCCATGTG',
#   '1',
#   'WT_TAGTTCCATGTG',
#   '-4.55637052302776',
#   '2.50469584131055'],
#  ['WT_GCCAAGCCTTCA',
#   'GCCAAGCCTTCA',
#   '1',
#   'WT_GCCAAGCCTTCA',
#   '-6.9727346112372',
#   '3.80605111048352'],
#  ['WT_CTGCACGTCTCC',
#   'CTGCACGTCTCC',
#   '1',
#   'WT_CTGCACGTCTCC',
#   '-6.78290729309481',
#   '21.1799991379669'],
#  ['WT_CAGTTAGCACTC',
#   'CAGTTAGCACTC',
#   '1',
#   'WT_CAGTTAGCACTC',
#   '-6.49086695133302',
#   '8.34361499426981'],
#  ['WT_CATAACATGTCG',
#   'CATAACATGTCG',
#   '1',
#   'WT_CATAACATGTCG',
#   '-6.92513336450836',
#   '16.3420614820631'],
#  ['WT_TAACCAGCAGAA',
#   'TAACCAGCAGAA',
#   '1',
#   'WT_TAACCAGCAGAA',
#   '-5.69115229005111',
#   '6.41204839923548'],
#  ['WT_CACATGTCGCCG',
#   'CACATGTCGCCG',
#   '1',
#   'WT_CACATGTCGCCG',
#   '-2.26234770264897',
#   '5.02172744380834'],
#  ['WT_GCCGACGCCAGT',
#   'GCCGACGCCAGT',
#   '1',
#   'WT_GCCGACGCCAGT',
#   '-9.17939841522402',
#   '3.46903519534125'],
#  ['WT_CGGAGCATATCN',
#   'CGGAGCATATCN',
#   '1',
#   'WT_CGGAGCATATCN',
#   '-6.76882937092891',
#   '3.95739884178318'],
#  ['WT_TTGTGAAACATT',
#   'TTGTGAAACATT',
#   '1',
#   'WT_TTGTGAAACATT',
#   '-9.20501187337506',
#   '18.4449741780474'],
#  ['WT_CATTGGCTAGAN',
#   'CATTGGCTAGAN',
#   '1',
#   'WT_CATTGGCTAGAN',
#   '-8.9638468184873',
#   '6.27789626522787'],
#  ['WT_TGGTTAGCCCCG',
#   'TGGTTAGCCCCG',
#   '1',
#   'WT_TGGTTAGCCCCG',
#   '-2.14669444505599',
#   '5.37440679921904'],
#  ['WT_AAGTAGAGCAAT',
#   'AAGTAGAGCAAT',
#   '1',
#   'WT_AAGTAGAGCAAT',
#   '-7.23793695838358',
#   '7.60166826709539'],
#  ['WT_GGCAATGATCAA',
#   'GGCAATGATCAA',
#   '1',
#   'WT_GGCAATGATCAA',
#   '-9.14974916244579',
#   '11.5362320786691'],
#  ['WT_CAAATTTGTAAA',
#   'CAAATTTGTAAA',
#   '1',
#   'WT_CAAATTTGTAAA',
#   '-12.2503375266834',
#   '5.06137828151238'],
#  ['WT_ACGACCAACTCA',
#   'ACGACCAACTCA',
#   '1',
#   'WT_ACGACCAACTCA',
#   '-6.47234294588918',
#   '8.92029651032443'],
#  ['WT_CCCAATAGCTCT',
#   'CCCAATAGCTCT',
#   '1',
#   'WT_CCCAATAGCTCT',
#   '-10.0355062330784',
#   '9.95923603326061'],
#  ['WT_GCCCACATTCCA',
#   'GCCCACATTCCA',
#   '4',
#   'WT_GCCCACATTCCA',
#   '0.629032453929238',
#   '7.22178703255105'],
#  ['WT_ATACGATGAAAA',
#   'ATACGATGAAAA',
#   '1',
#   'WT_ATACGATGAAAA',
#   '-7.10819799842553',
#   '5.98671379494609'],
#  ['WT_TGTGTTACAGGC',
#   'TGTGTTACAGGC',
#   '1',
#   'WT_TGTGTTACAGGC',
#   '-15.3926516143408',
#   '11.6695944879164'],
#  ['WT_CCGTCATCTTGA',
#   'CCGTCATCTTGA',
#   '1',
#   'WT_CCGTCATCTTGA',
#   '-11.8524219900435',
#   '4.78801579429279'],
#  ['WT_ACATTCTCGAGT',
#   'ACATTCTCGAGT',
#   '1',
#   'WT_ACATTCTCGAGT',
#   '-10.4511844381322',
#   '-5.64067405599792'],
#  ['WT_AGGACGGGTGTA',
#   'AGGACGGGTGTA',
#   '1',
#   'WT_AGGACGGGTGTA',
#   '-8.26145539633524',
#   '6.48152748164618'],
#  ['WT_TGTGGTCCGTCG',
#   'TGTGGTCCGTCG',
#   '4',
#   'WT_TGTGGTCCGTCG',
#   '-8.62475405874008',
#   '20.3802648021785'],
#  ['WT_AGAGCATAATCA',
#   'AGAGCATAATCA',
#   '6',
#   'WT_AGAGCATAATCA',
#   '6.84881931135675',
#   '-6.9136860846378'],
#  ['WT_AGGCTATGTGGT',
#   'AGGCTATGTGGT',
#   '1',
#   'WT_AGGCTATGTGGT',
#   '-3.63073474556681',
#   '12.0333629742457'],
#  ['WT_CTTTAGTGCATT',
#   'CTTTAGTGCATT',
#   '1',
#   'WT_CTTTAGTGCATT',
#   '-11.2203468398488',
#   '1.23648130445052'],
#  ['WT_CTGCACCTTACT',
#   'CTGCACCTTACT',
#   '1',
#   'WT_CTGCACCTTACT',
#   '-5.12902647330614',
#   '7.83945693224457'],
#  ['WT_TTCCCCCGCCGG',
#   'TTCCCCCGCCGG',
#   '1',
#   'WT_TTCCCCCGCCGG',
#   '-8.38685946069561',
#   '9.03502503903975'],
#  ['WT_CCCAAGCTGATA',
#   'CCCAAGCTGATA',
#   '1',
#   'WT_CCCAAGCTGATA',
#   '-9.9960389484622',
#   '10.0563304769904'],
#  ['WT_TTACGCCTTCTT',
#   'TTACGCCTTCTT',
#   '1',
#   'WT_TTACGCCTTCTT',
#   '-1.81275818376972',
#   '6.95275567250466'],
#  ['WT_CAGGGTATTCTA',
#   'CAGGGTATTCTA',
#   '1',
#   'WT_CAGGGTATTCTA',
#   '-10.4332341167494',
#   '11.2046950978887'],
#  ['WT_TAGGCGAGCAAN',
#   'TAGGCGAGCAAN',
#   '1',
#   'WT_TAGGCGAGCAAN',
#   '-7.44072954819947',
#   '17.8751868256665'],
#  ['WT_AGGGTAACGTGG',
#   'AGGGTAACGTGG',
#   '1',
#   'WT_AGGGTAACGTGG',
#   '-15.509688351069',
#   '10.1948998054578'],
#  ['WT_AGGGGGCCATCG',
#   'AGGGGGCCATCG',
#   '1',
#   'WT_AGGGGGCCATCG',
#   '-10.342585875033',
#   '4.33711579166155'],
#  ['WT_TCGTCAATTGCT',
#   'TCGTCAATTGCT',
#   '1',
#   'WT_TCGTCAATTGCT',
#   '1.37526122468681',
#   '8.15696239068817'],
#  ['WT_ATCGCCGCGGAT',
#   'ATCGCCGCGGAT',
#   '1',
#   'WT_ATCGCCGCGGAT',
#   '-4.65365711138621',
#   '19.4456944232472'],
#  ['WT_CCATACTGGCTG',
#   'CCATACTGGCTG',
#   '1',
#   'WT_CCATACTGGCTG',
#   '-4.70294839515056',
#   '3.50980878999477'],
#  ['WT_GTAAAAGTGCCA',
#   'GTAAAAGTGCCA',
#   '3',
#   'WT_GTAAAAGTGCCA',
#   '4.07733974583502',
#   '2.59594463859029'],
#  ['WT_TACGTCGGTTAC',
#   'TACGTCGGTTAC',
#   '1',
#   'WT_TACGTCGGTTAC',
#   '6.31844920347829',
#   '-7.84645564259013'],
#  ['WT_TTTGTACCCGTC',
#   'TTTGTACCCGTC',
#   '1',
#   'WT_TTTGTACCCGTC',
#   '-10.1589138971821',
#   '6.39460025868263'],
#  ['WT_TGCTACCACGTG',
#   'TGCTACCACGTG',
#   '1',
#   'WT_TGCTACCACGTG',
#   '-0.820779078664905',
#   '4.89422699039147'],
#  ['WT_CTCGACAGGGGC',
#   'CTCGACAGGGGC',
#   '1',
#   'WT_CTCGACAGGGGC',
#   '-3.33662708458725',
#   '14.6400879520404'],
#  ['WT_TCCGCTCTGAGT',
#   'TCCGCTCTGAGT',
#   '1',
#   'WT_TCCGCTCTGAGT',
#   '-15.2131611936529',
#   '0.340646105231708'],
#  ['WT_TATAGAATCAAG',
#   'TATAGAATCAAG',
#   '1',
#   'WT_TATAGAATCAAG',
#   '-10.5538657969522',
#   '8.33101332280701'],
#  ['WT_TTAGTTCAAAAC',
#   'TTAGTTCAAAAC',
#   '1',
#   'WT_TTAGTTCAAAAC',
#   '-7.80684483503116',
#   '8.81334803658805'],
#  ['WT_TAGGATTCGGAG',
#   'TAGGATTCGGAG',
#   '10',
#   'WT_TAGGATTCGGAG',
#   '-14.5116340120814',
#   '-4.19813352822368'],
#  ['WT_CCACGGTACGTT',
#   'CCACGGTACGTT',
#   '3',
#   'WT_CCACGGTACGTT',
#   '19.3356098630011',
#   '-2.92746112803836'],
#  ['WT_CCATCACCCAGC',
#   'CCATCACCCAGC',
#   '1',
#   'WT_CCATCACCCAGC',
#   '-6.51036145090278',
#   '15.2658368860585'],
#  ['WT_TTCAACACACGT',
#   'TTCAACACACGT',
#   '1',
#   'WT_TTCAACACACGT',
#   '-6.71003947602874',
#   '5.80969212971604'],
#  ['WT_GGTACGCGCGCA',
#   'GGTACGCGCGCA',
#   '4',
#   'WT_GGTACGCGCGCA',
#   '-6.41275799870209',
#   '29.6970332553865'],
#  ['WT_TAACCTGCGTTA',
#   'TAACCTGCGTTA',
#   '1',
#   'WT_TAACCTGCGTTA',
#   '-0.930335744450797',
#   '7.04506383819036'],
#  ['WT_AGCTAAGGAACA',
#   'AGCTAAGGAACA',
#   '1',
#   'WT_AGCTAAGGAACA',
#   '-10.6443532083171',
#   '14.4585065572414'],
#  ['WT_GTGATCTTCCTG',
#   'GTGATCTTCCTG',
#   '4',
#   'WT_GTGATCTTCCTG',
#   '4.11562998450179',
#   '22.5939837884058'],
#  ['WT_CCGCAGACTCGA',
#   'CCGCAGACTCGA',
#   '1',
#   'WT_CCGCAGACTCGA',
#   '-6.62347313933053',
#   '19.934073351798'],
#  ['WT_AGTTCAATTATA',
#   'AGTTCAATTATA',
#   '1',
#   'WT_AGTTCAATTATA',
#   '-9.82279348482961',
#   '7.12107962982197'],
#  ['WT_GCTGGTTTTGCC',
#   'GCTGGTTTTGCC',
#   '3',
#   'WT_GCTGGTTTTGCC',
#   '18.6362499045849',
#   '-3.08230788864435'],
#  ['WT_CCACAGTCACTT',
#   'CCACAGTCACTT',
#   '1',
#   'WT_CCACAGTCACTT',
#   '-14.6518822119623',
#   '6.49426998738532'],
#  ['WT_GTGGGGAGGCAG',
#   'GTGGGGAGGCAG',
#   '1',
#   'WT_GTGGGGAGGCAG',
#   '-9.865736813564',
#   '10.5529138881539'],
#  ['WT_ATTATTGATAGA',
#   'ATTATTGATAGA',
#   '1',
#   'WT_ATTATTGATAGA',
#   '1.02319749915613',
#   '6.3787082473463'],
#  ['WT_CATCCACAACTC',
#   'CATCCACAACTC',
#   '10',
#   'WT_CATCCACAACTC',
#   '-14.889779199453',
#   '-3.83267795111481'],
#  ['WT_ACGACTACGACA',
#   'ACGACTACGACA',
#   '1',
#   'WT_ACGACTACGACA',
#   '-11.3562463830796',
#   '6.63385183028339'],
#  ['WT_ACCGATATCTCA',
#   'ACCGATATCTCA',
#   '1',
#   'WT_ACCGATATCTCA',
#   '-3.55703467150939',
#   '-12.5894703702423'],
#  ['WT_AACGGGTTCTCC',
#   'AACGGGTTCTCC',
#   '1',
#   'WT_AACGGGTTCTCC',
#   '-2.09184461225415',
#   '10.8155074495684'],
#  ['WT_AAAGCATGATGC',
#   'AAAGCATGATGC',
#   '1',
#   'WT_AAAGCATGATGC',
#   '-4.57877319585126',
#   '16.4029000385964'],
#  ['WT_GTCTCCTGTATG',
#   'GTCTCCTGTATG',
#   '1',
#   'WT_GTCTCCTGTATG',
#   '-10.1980283224311',
#   '4.34882126518059'],
#  ['WT_CTGTGTAATATA',
#   'CTGTGTAATATA',
#   '1',
#   'WT_CTGTGTAATATA',
#   '-7.68747426849756',
#   '5.88146595205728'],
#  ['WT_AGTCAAATAGTA',
#   'AGTCAAATAGTA',
#   '1',
#   'WT_AGTCAAATAGTA',
#   '-10.9615996823265',
#   '6.9063723296553'],
#  ['WT_GGTTGGCGACGT',
#   'GGTTGGCGACGT',
#   '1',
#   'WT_GGTTGGCGACGT',
#   '-11.5964181415899',
#   '6.78881115701276'],
#  ['WT_GGGCAAAATGTN',
#   'GGGCAAAATGTN',
#   '4',
#   'WT_GGGCAAAATGTN',
#   '1.51379599323215',
#   '7.48700005562854'],
#  ['WT_CGACAACGATGA',
#   'CGACAACGATGA',
#   '1',
#   'WT_CGACAACGATGA',
#   '-4.81978144409187',
#   '16.5975745688255'],
#  ['WT_CACCGCCAAAGG',
#   'CACCGCCAAAGG',
#   '1',
#   'WT_CACCGCCAAAGG',
#   '-4.99551630628277',
#   '14.3424161591458'],
#  ['GF_CGCCGCCCGTCN',
#   'CGCCGCCCGTCN',
#   '1',
#   'GF_CGCCGCCCGTCN',
#   '-10.9293654297179',
#   '-1.67650490065785'],
#  ['GF_ACAAGTTTGTTC',
#   'ACAAGTTTGTTC',
#   '1',
#   'GF_ACAAGTTTGTTC',
#   '-21.9841693394706',
#   '17.0855561751026'],
#  ['GF_CCTGATCATCTC',
#   'CCTGATCATCTC',
#   '1',
#   'GF_CCTGATCATCTC',
#   '-21.2420764125155',
#   '15.2486805910391'],
#  ['GF_ATAAAGGAACAG',
#   'ATAAAGGAACAG',
#   '1',
#   'GF_ATAAAGGAACAG',
#   '-19.8708600301988',
#   '16.0629875672153'],
#  ['GF_CGTAGTTTAGTC',
#   'CGTAGTTTAGTC',
#   '1',
#   'GF_CGTAGTTTAGTC',
#   '-21.4433251213148',
#   '19.350603585441'],
#  ['GF_CGAAAGCCCAGG',
#   'CGAAAGCCCAGG',
#   '1',
#   'GF_CGAAAGCCCAGG',
#   '-12.3190251555543',
#   '14.2709150528636'],
#  ['GF_CTGTCGGAACAN',
#   'CTGTCGGAACAN',
#   '1',
#   'GF_CTGTCGGAACAN',
#   '-9.65905866517629',
#   '-1.64936224863809'],
#  ['GF_AGTCCTTGCAGN',
#   'AGTCCTTGCAGN',
#   '1',
#   'GF_AGTCCTTGCAGN',
#   '-16.7051276653029',
#   '16.577321516691'],
#  ['GF_AGCACTTGGGCN',
#   'AGCACTTGGGCN',
#   '1',
#   'GF_AGCACTTGGGCN',
#   '-19.8627356898847',
#   '16.7529902886222'],
#  ['GF_TGGTTTGCTTTT',
#   'TGGTTTGCTTTT',
#   '1',
#   'GF_TGGTTTGCTTTT',
#   '-23.0058895660529',
#   '15.4985298756821'],
#  ['GF_CTAGCCCATTTN',
#   'CTAGCCCATTTN',
#   '1',
#   'GF_CTAGCCCATTTN',
#   '-20.8862146051324',
#   '14.6568659557494'],
#  ['GF_CGTACCCTAGAN',
#   'CGTACCCTAGAN',
#   '1',
#   'GF_CGTACCCTAGAN',
#   '-18.5230215347565',
#   '16.3241720643492'],
#  ['GF_ACTTAGTGACAN',
#   'ACTTAGTGACAN',
#   '1',
#   'GF_ACTTAGTGACAN',
#   '-13.8786817761056',
#   '10.3947334769166'],
#  ['GF_TAGGTGCTCGGG',
#   'TAGGTGCTCGGG',
#   '1',
#   'GF_TAGGTGCTCGGG',
#   '-18.2702580061473',
#   '17.6832502433928'],
#  ['GF_ATGACAGAGACG',
#   'ATGACAGAGACG',
#   '1',
#   'GF_ATGACAGAGACG',
#   '-20.7310951025251',
#   '15.9134739271164'],
#  ['GF_AGTTTGTATTAG',
#   'AGTTTGTATTAG',
#   '1',
#   'GF_AGTTTGTATTAG',
#   '-18.4313053949265',
#   '19.279107555563'],
#  ['GF_TTCTTGTAGCCG',
#   'TTCTTGTAGCCG',
#   '1',
#   'GF_TTCTTGTAGCCG',
#   '-18.5381147485883',
#   '14.1868699409655'],
#  ['GF_TAGGCTAGCTCG',
#   'TAGGCTAGCTCG',
#   '1',
#   'GF_TAGGCTAGCTCG',
#   '-17.8221792727819',
#   '15.1906383772882'],
#  ['GF_GGCTCAAAGGTG',
#   'GGCTCAAAGGTG',
#   '1',
#   'GF_GGCTCAAAGGTG',
#   '-18.1693605221861',
#   '8.19391601886768'],
#  ['GF_CCTTCCGCGCAN',
#   'CCTTCCGCGCAN',
#   '1',
#   'GF_CCTTCCGCGCAN',
#   '-14.2900258680984',
#   '10.2022320774303'],
#  ['GF_GTCAAAGAGTCA',
#   'GTCAAAGAGTCA',
#   '1',
#   'GF_GTCAAAGAGTCA',
#   '-22.4702015559415',
#   '15.9732948757067'],
#  ['GF_AGTCAAGCTCTG',
#   'AGTCAAGCTCTG',
#   '1',
#   'GF_AGTCAAGCTCTG',
#   '-16.3582366226422',
#   '13.77628382703'],
#  ['GF_CTCCCGGCCTAT',
#   'CTCCCGGCCTAT',
#   '1',
#   'GF_CTCCCGGCCTAT',
#   '-9.45483878302914',
#   '-1.84481046898676'],
#  ['GF_GCTATTAACGTC',
#   'GCTATTAACGTC',
#   '1',
#   'GF_GCTATTAACGTC',
#   '-21.5061922776159',
#   '15.3091330284897'],
#  ['GF_AATGTGTCGACT',
#   'AATGTGTCGACT',
#   '1',
#   'GF_AATGTGTCGACT',
#   '-12.3041262621497',
#   '15.9639946798075'],
#  ['GF_TGAGGCCATAGA',
#   'TGAGGCCATAGA',
#   '1',
#   'GF_TGAGGCCATAGA',
#   '-17.0292763850876',
#   '17.2848460608657'],
#  ['GF_TATCAATGGCAA',
#   'TATCAATGGCAA',
#   '1',
#   'GF_TATCAATGGCAA',
#   '-17.2977305043122',
#   '17.0980276246681'],
#  ['WT_TTTTCTCCTTAC',
#   'TTTTCTCCTTAC',
#   '1',
#   'WT_TTTTCTCCTTAC',
#   '-15.086417801758',
#   '13.7216695102832'],
#  ['WT_TTTTGAACGTTA',
#   'TTTTGAACGTTA',
#   '1',
#   'WT_TTTTGAACGTTA',
#   '-22.4181508555559',
#   '16.2150144121869'],
#  ['WT_TTCATCTGGATC',
#   'TTCATCTGGATC',
#   '1',
#   'WT_TTCATCTGGATC',
#   '-13.3937645428651',
#   '4.98607851767857'],
#  ['WT_AGGTTCTATCCT',
#   'AGGTTCTATCCT',
#   '1',
#   'WT_AGGTTCTATCCT',
#   '-18.5223319930909',
#   '9.23402325204867'],
#  ['WT_CTATGTGTGACC',
#   'CTATGTGTGACC',
#   '1',
#   'WT_CTATGTGTGACC',
#   '-17.7292888319746',
#   '9.43707688603586'],
#  ['WT_AGCACAGAGGGG',
#   'AGCACAGAGGGG',
#   '1',
#   'WT_AGCACAGAGGGG',
#   '-21.850973683014',
#   '17.4052438437971'],
#  ['WT_CAATTTACCCAT',
#   'CAATTTACCCAT',
#   '1',
#   'WT_CAATTTACCCAT',
#   '-17.6543852262106',
#   '9.48328056219619'],
#  ['WT_GGCGGTAATGGA',
#   'GGCGGTAATGGA',
#   '1',
#   'WT_GGCGGTAATGGA',
#   '-21.8064456134572',
#   '9.11016807054307'],
#  ['WT_TCACACCCGTGT',
#   'TCACACCCGTGT',
#   '1',
#   'WT_TCACACCCGTGT',
#   '-21.3075842092862',
#   '17.3728684225972'],
#  ['WT_TCTTGCCGACTC',
#   'TCTTGCCGACTC',
#   '1',
#   'WT_TCTTGCCGACTC',
#   '-17.8068488579137',
#   '8.06563616723802'],
#  ['WT_ACTCGAGACAAC',
#   'ACTCGAGACAAC',
#   '1',
#   'WT_ACTCGAGACAAC',
#   '-18.9339472284427',
#   '16.2052871731177'],
#  ['WT_ACCGCGGGTGCT',
#   'ACCGCGGGTGCT',
#   '11',
#   'WT_ACCGCGGGTGCT',
#   '-3.03582530781289',
#   '-4.79029077653542'],
#  ['WT_GTAGCGTCCAAC',
#   'GTAGCGTCCAAC',
#   '1',
#   'WT_GTAGCGTCCAAC',
#   '-12.7411995516028',
#   '7.14444058733584'],
#  ['WT_TTACTCGCAGAA',
#   'TTACTCGCAGAA',
#   '1',
#   'WT_TTACTCGCAGAA',
#   '-21.5828442578308',
#   '19.0876567445681'],
#  ['WT_TTGTGGGGCTCT',
#   'TTGTGGGGCTCT',
#   '1',
#   'WT_TTGTGGGGCTCT',
#   '-20.3192848077262',
#   '15.5312600850256'],
#  ['WT_ATGGGGAACTCA',
#   'ATGGGGAACTCA',
#   '1',
#   'WT_ATGGGGAACTCA',
#   '-3.59617044454576',
#   '-4.41047997295008'],
#  ['WT_CCTGTTTCACTT',
#   'CCTGTTTCACTT',
#   '1',
#   'WT_CCTGTTTCACTT',
#   '-18.2324062939051',
#   '15.2231984830597'],
#  ['WT_AAGTGCCGGGTC',
#   'AAGTGCCGGGTC',
#   '1',
#   'WT_AAGTGCCGGGTC',
#   '-18.6613638528128',
#   '10.9242628348602'],
#  ['WT_CGACGTCGCGTT',
#   'CGACGTCGCGTT',
#   '11',
#   'WT_CGACGTCGCGTT',
#   '-3.2259498336672',
#   '-4.6373209554852'],
#  ['WT_TCTTTATCCTCN',
#   'TCTTTATCCTCN',
#   '1',
#   'WT_TCTTTATCCTCN',
#   '-19.8955768094272',
#   '16.3632160521981'],
#  ...]

# %%
my_data = rand_draw(mtx=mtx, meta=meta, num_to_select=20)

# %%
my_data.A_clusTocell_dic_generator()
my_data.B_cellTogene_dic_generator()

print(my_data.num_to_select)
my_data.C_random_selector(num_to_select=14)
print(my_data.num_to_select)

my_data.D_avg_gene()
my_data.E_briefing()
# Out:
# Key Cell ID: GATCAGTTTCCN - Assigned Cluster: 0 - Number of Cell: 14
# Key Cell ID: CATGATCCTTGC - Assigned Cluster: 0 - Number of Cell: 14
# Key Cell ID: AGCGATTAGTTC - Assigned Cluster: 0 - Number of Cell: 14
# Key Cell ID: CCGAGCAGGACT - Assigned Cluster: 0 - Number of Cell: 14
# Key Cell ID: TAGTATCCTTGA - Assigned Cluster: 0 - Number of Cell: 14
# Key Cell ID: GTCCTAAAGGAT - Assigned Cluster: 0 - Number of Cell: 14
# Key Cell ID: TCTCAGTGAGTG - Assigned Cluster: 0 - Number of Cell: 14
# Key Cell ID: CCCTTCGTGTTA - Assigned Cluster: 0 - Number of Cell: 14
# Key Cell ID: TGTGCGGAGTTC - Assigned Cluster: 0 - Number of Cell: 14
# Key Cell ID: AGAACATAATCC - Assigned Cluster: 0 - Number of Cell: 14
# Key Cell ID: TGTGAACTCGTA - Assigned Cluster: 0 - Number of Cell: 14
# Key Cell ID: TATCAGCAGACG - Assigned Cluster: 0 - Number of Cell: 14
# Key Cell ID: ACGTTACGGAGT - Assigned Cluster: 0 - Number of Cell: 14
# Key Cell ID: TTAACTGGAGCN - Assigned Cluster: 0 - Number of Cell: 14
# Key Cell ID: GCCTACCTCCCN - Assigned Cluster: 0 - Number of Cell: 4
# Key Cell ID: GCACCCAGGTAN - Assigned Cluster: 1 - Number of Cell: 14
# Key Cell ID: ACGTAGGATGTG - Assigned Cluster: 1 - Number of Cell: 14
# Key Cell ID: AGTTCAATTATA - Assigned Cluster: 1 - Number of Cell: 14
# Key Cell ID: AGTACACGTATC - Assigned Cluster: 1 - Number of Cell: 14
# Key Cell ID: AGTCCTTGCAGN - Assigned Cluster: 1 - Number of Cell: 14
# Key Cell ID: TTGTGGGGCTCT - Assigned Cluster: 1 - Number of Cell: 14
# Key Cell ID: AGGAATCTGCCT - Assigned Cluster: 1 - Number of Cell: 14
# Key Cell ID: TATAAGAGTGCN - Assigned Cluster: 1 - Number of Cell: 14
# Key Cell ID: GGCGGTAATGGA - Assigned Cluster: 1 - Number of Cell: 14
# Key Cell ID: TTGGGACCTTTA - Assigned Cluster: 1 - Number of Cell: 14
# Key Cell ID: ATAAAGGAACAG - Assigned Cluster: 1 - Number of Cell: 14
# Key Cell ID: CCTTCCGCGCAN - Assigned Cluster: 1 - Number of Cell: 14
# Key Cell ID: CAAATTTGTAAA - Assigned Cluster: 1 - Number of Cell: 14
# Key Cell ID: GGTACCCTGCCA - Assigned Cluster: 1 - Number of Cell: 14
# Key Cell ID: CTTGCATATTGN - Assigned Cluster: 1 - Number of Cell: 4
# Key Cell ID: TTCTCAGTTATA - Assigned Cluster: 10 - Number of Cell: 14
# Key Cell ID: AAACACCGGAAT - Assigned Cluster: 10 - Number of Cell: 14
# Key Cell ID: TCCGAGTACCAG - Assigned Cluster: 10 - Number of Cell: 14
# Key Cell ID: TGCCCACCTCAN - Assigned Cluster: 10 - Number of Cell: 14
# Key Cell ID: TGGTTTCCGGGN - Assigned Cluster: 10 - Number of Cell: 14
# Key Cell ID: GTACCTCGCTCG - Assigned Cluster: 10 - Number of Cell: 14
# Key Cell ID: GAACCACAAACN - Assigned Cluster: 10 - Number of Cell: 14
# Key Cell ID: CACATGCACTGT - Assigned Cluster: 10 - Number of Cell: 14
# Key Cell ID: TAGCTGCCCTCG - Assigned Cluster: 10 - Number of Cell: 14
# Key Cell ID: GTGCGCACAGGT - Assigned Cluster: 10 - Number of Cell: 14
# Key Cell ID: AGCATTCCAGTA - Assigned Cluster: 10 - Number of Cell: 14
# Key Cell ID: TGCTGGCGTGGC - Assigned Cluster: 10 - Number of Cell: 14
# Key Cell ID: CACCTGCCCAAT - Assigned Cluster: 10 - Number of Cell: 14
# Key Cell ID: TAAGCCTCACCT - Assigned Cluster: 10 - Number of Cell: 14
# Key Cell ID: ACTATATCCTTC - Assigned Cluster: 10 - Number of Cell: 4
# Key Cell ID: CGAAAGGAATCT - Assigned Cluster: 11 - Number of Cell: 14
# Key Cell ID: CGCAGCTCAAGN - Assigned Cluster: 11 - Number of Cell: 14
# Key Cell ID: GCAAGTCCCCCC - Assigned Cluster: 11 - Number of Cell: 14
# Key Cell ID: CGCCCAGTCGAG - Assigned Cluster: 11 - Number of Cell: 14
# Key Cell ID: GAAGGTAGCCGG - Assigned Cluster: 11 - Number of Cell: 14
# Key Cell ID: TGGTAGGCATTC - Assigned Cluster: 11 - Number of Cell: 14
# Key Cell ID: TTGATCGCGGGA - Assigned Cluster: 11 - Number of Cell: 14
# Key Cell ID: TTGATAAATCCA - Assigned Cluster: 11 - Number of Cell: 14
# Key Cell ID: AACGTAGTCCAC - Assigned Cluster: 11 - Number of Cell: 14
# Key Cell ID: GAGGAACGTCCG - Assigned Cluster: 11 - Number of Cell: 6
# Key Cell ID: GCGGGATTTTGA - Assigned Cluster: 12 - Number of Cell: 14
# Key Cell ID: GAGTCAGATTAA - Assigned Cluster: 12 - Number of Cell: 14
# Key Cell ID: ATAAGCTCTTTN - Assigned Cluster: 12 - Number of Cell: 14
# Key Cell ID: GACCGGATATTC - Assigned Cluster: 12 - Number of Cell: 14
# Key Cell ID: CGGAAGATCCTN - Assigned Cluster: 12 - Number of Cell: 1
# Key Cell ID: GGATAAAATACC - Assigned Cluster: 2 - Number of Cell: 14
# Key Cell ID: TAAATTGTTCGG - Assigned Cluster: 2 - Number of Cell: 14
# Key Cell ID: ATACTAAGGTTA - Assigned Cluster: 2 - Number of Cell: 14
# Key Cell ID: GCAGTCTATCAT - Assigned Cluster: 2 - Number of Cell: 14
# Key Cell ID: TGCTACTCACTN - Assigned Cluster: 2 - Number of Cell: 14
# Key Cell ID: CCGTGGATTTGC - Assigned Cluster: 2 - Number of Cell: 14
# Key Cell ID: ACTCAGTTTGAG - Assigned Cluster: 2 - Number of Cell: 14
# Key Cell ID: CGGAGGAGGCGN - Assigned Cluster: 2 - Number of Cell: 14
# Key Cell ID: GCGAGCGAGACA - Assigned Cluster: 2 - Number of Cell: 14
# Key Cell ID: CGTCTACACGTC - Assigned Cluster: 2 - Number of Cell: 14
# Key Cell ID: TTACGAGTTACC - Assigned Cluster: 2 - Number of Cell: 14
# Key Cell ID: GTTCTTTTGGTA - Assigned Cluster: 2 - Number of Cell: 14
# Key Cell ID: TCCATCAGGAAN - Assigned Cluster: 2 - Number of Cell: 14
# Key Cell ID: CCTTCCACGACG - Assigned Cluster: 2 - Number of Cell: 14
# Key Cell ID: GGATCACCTTTT - Assigned Cluster: 2 - Number of Cell: 4
# Key Cell ID: CGTCGAGCTTTA - Assigned Cluster: 3 - Number of Cell: 14
# Key Cell ID: GAACCGCCTGCT - Assigned Cluster: 3 - Number of Cell: 14
# Key Cell ID: AGAGCGTGAGGT - Assigned Cluster: 3 - Number of Cell: 14
# Key Cell ID: CAAATCGAGCAT - Assigned Cluster: 3 - Number of Cell: 14
# Key Cell ID: AGGACAAAAGAA - Assigned Cluster: 3 - Number of Cell: 14
# Key Cell ID: GGAGTTGCTGAT - Assigned Cluster: 3 - Number of Cell: 14
# Key Cell ID: CAATGTTAGCAT - Assigned Cluster: 3 - Number of Cell: 14
# Key Cell ID: AGCACTGAGTCA - Assigned Cluster: 3 - Number of Cell: 14
# Key Cell ID: CCGAGATGCAGT - Assigned Cluster: 3 - Number of Cell: 14
# Key Cell ID: TCAGGGCGTTAA - Assigned Cluster: 3 - Number of Cell: 14
# Key Cell ID: GCGACGTTAACC - Assigned Cluster: 3 - Number of Cell: 14
# Key Cell ID: TCTCTTTAACGT - Assigned Cluster: 3 - Number of Cell: 14
# Key Cell ID: GTAGGACACGCT - Assigned Cluster: 3 - Number of Cell: 14
# Key Cell ID: AGTTCCGACACG - Assigned Cluster: 3 - Number of Cell: 14
# Key Cell ID: GCGGTATGATCN - Assigned Cluster: 3 - Number of Cell: 4
# Key Cell ID: TAAGGAGTTTCC - Assigned Cluster: 4 - Number of Cell: 14
# Key Cell ID: GATCCTGTCACT - Assigned Cluster: 4 - Number of Cell: 14
# Key Cell ID: AGGAGGCCGTTA - Assigned Cluster: 4 - Number of Cell: 14
# Key Cell ID: AGGGCATGGTAG - Assigned Cluster: 4 - Number of Cell: 14
# Key Cell ID: ACCGATGTACCC - Assigned Cluster: 4 - Number of Cell: 14
# Key Cell ID: CTTTATCATTCC - Assigned Cluster: 4 - Number of Cell: 14
# Key Cell ID: CCTGGTAAATTT - Assigned Cluster: 4 - Number of Cell: 14
# Key Cell ID: CGAACGGACAGN - Assigned Cluster: 4 - Number of Cell: 14
# Key Cell ID: TTTTGTCTAATT - Assigned Cluster: 4 - Number of Cell: 14
# Key Cell ID: CCATTTGACCGC - Assigned Cluster: 4 - Number of Cell: 14
# Key Cell ID: GATGTACAGTTT - Assigned Cluster: 4 - Number of Cell: 14
# Key Cell ID: TGTAGGACTCTC - Assigned Cluster: 4 - Number of Cell: 14
# Key Cell ID: GGCGATACGGAC - Assigned Cluster: 4 - Number of Cell: 14
# Key Cell ID: TTCGACTAGTCA - Assigned Cluster: 4 - Number of Cell: 14
# Key Cell ID: TCACCGCGGAGT - Assigned Cluster: 4 - Number of Cell: 4
# Key Cell ID: TTGGATGTTGCG - Assigned Cluster: 5 - Number of Cell: 14
# Key Cell ID: GGGGAACAACAC - Assigned Cluster: 5 - Number of Cell: 14
# Key Cell ID: CCCATACGAACG - Assigned Cluster: 5 - Number of Cell: 14
# Key Cell ID: GGGTTGACGAGT - Assigned Cluster: 5 - Number of Cell: 14
# Key Cell ID: TTGAACTGTCCT - Assigned Cluster: 5 - Number of Cell: 14
# Key Cell ID: ACCCCAAGACGN - Assigned Cluster: 5 - Number of Cell: 14
# Key Cell ID: ACGGAAGTTCCC - Assigned Cluster: 5 - Number of Cell: 14
# Key Cell ID: CAGACACCAGAA - Assigned Cluster: 5 - Number of Cell: 14
# Key Cell ID: TTTGCGCTGATC - Assigned Cluster: 5 - Number of Cell: 14
# Key Cell ID: ATCAAGGCTATT - Assigned Cluster: 5 - Number of Cell: 14
# Key Cell ID: CTGGCCCGTACC - Assigned Cluster: 5 - Number of Cell: 14
# Key Cell ID: GTCAAGTGTCAN - Assigned Cluster: 5 - Number of Cell: 14
# Key Cell ID: TCCGTATCGCTN - Assigned Cluster: 5 - Number of Cell: 14
# Key Cell ID: TATTTGACGGTC - Assigned Cluster: 5 - Number of Cell: 14
# Key Cell ID: TGGTTTCGCCCN - Assigned Cluster: 5 - Number of Cell: 4
# Key Cell ID: CAACGGAACGTC - Assigned Cluster: 6 - Number of Cell: 14
# Key Cell ID: CTGGCTGCAGGT - Assigned Cluster: 6 - Number of Cell: 14
# Key Cell ID: TGTGGGCACTTC - Assigned Cluster: 6 - Number of Cell: 14
# Key Cell ID: TCGCAGTCGATG - Assigned Cluster: 6 - Number of Cell: 14
# Key Cell ID: CAACCCATACCG - Assigned Cluster: 6 - Number of Cell: 14
# Key Cell ID: GGGATCCCCGCA - Assigned Cluster: 6 - Number of Cell: 14
# Key Cell ID: TGAATGACCCTT - Assigned Cluster: 6 - Number of Cell: 14
# Key Cell ID: ACCGTTGGGTAG - Assigned Cluster: 6 - Number of Cell: 14
# Key Cell ID: ATCGTTCGTACC - Assigned Cluster: 6 - Number of Cell: 14
# Key Cell ID: CTATACCCCGGT - Assigned Cluster: 6 - Number of Cell: 14
# Key Cell ID: CAGGTCGGAGGC - Assigned Cluster: 6 - Number of Cell: 14
# Key Cell ID: ATTGAGGACATC - Assigned Cluster: 6 - Number of Cell: 14
# Key Cell ID: TCCCGTACGGTT - Assigned Cluster: 6 - Number of Cell: 14
# Key Cell ID: ACGCCACGAGGC - Assigned Cluster: 6 - Number of Cell: 14
# Key Cell ID: CCTTTTTCGGAA - Assigned Cluster: 6 - Number of Cell: 4
# Key Cell ID: ACCGCTGAGTGC - Assigned Cluster: 7 - Number of Cell: 14
# Key Cell ID: CCATTCGATTGC - Assigned Cluster: 7 - Number of Cell: 14
# Key Cell ID: TGAGTCGTAGCC - Assigned Cluster: 7 - Number of Cell: 14
# Key Cell ID: ATCTGAGAGATT - Assigned Cluster: 7 - Number of Cell: 14
# Key Cell ID: TCTGTAGGGTGG - Assigned Cluster: 7 - Number of Cell: 14
# Key Cell ID: GCAAACGAGAAG - Assigned Cluster: 7 - Number of Cell: 14
# Key Cell ID: TAAATACGGTTG - Assigned Cluster: 7 - Number of Cell: 14
# Key Cell ID: TACCTGAGACAA - Assigned Cluster: 7 - Number of Cell: 14
# Key Cell ID: CAATTACAAGTC - Assigned Cluster: 7 - Number of Cell: 14
# Key Cell ID: CGGCCACGAGTA - Assigned Cluster: 7 - Number of Cell: 14
# Key Cell ID: TCGAGGCACTTC - Assigned Cluster: 7 - Number of Cell: 14
# Key Cell ID: ACTGAACTTGCT - Assigned Cluster: 7 - Number of Cell: 14
# Key Cell ID: GCTAGCCGCGGG - Assigned Cluster: 7 - Number of Cell: 14
# Key Cell ID: TATCTACGTTAN - Assigned Cluster: 7 - Number of Cell: 14
# Key Cell ID: ATGCGCCCTTCG - Assigned Cluster: 7 - Number of Cell: 4
# Key Cell ID: CTACACGGTCGT - Assigned Cluster: 8 - Number of Cell: 14
# Key Cell ID: ACGTGGCTCATG - Assigned Cluster: 8 - Number of Cell: 14
# Key Cell ID: CTCTTTGCCCGN - Assigned Cluster: 8 - Number of Cell: 14
# Key Cell ID: ATAGGTGTGTTG - Assigned Cluster: 8 - Number of Cell: 14
# Key Cell ID: CCGCCAGTCCGT - Assigned Cluster: 8 - Number of Cell: 14
# Key Cell ID: CACATCTATCTG - Assigned Cluster: 8 - Number of Cell: 14
# Key Cell ID: AGGTTATTCCAG - Assigned Cluster: 8 - Number of Cell: 14
# Key Cell ID: GATAATCTTTCG - Assigned Cluster: 8 - Number of Cell: 14
# Key Cell ID: TATCCTGTGGGC - Assigned Cluster: 8 - Number of Cell: 14
# Key Cell ID: CACTTTATATGG - Assigned Cluster: 8 - Number of Cell: 14
# Key Cell ID: TTCAGACGTCAT - Assigned Cluster: 8 - Number of Cell: 14
# Key Cell ID: GCATCAGGACTG - Assigned Cluster: 8 - Number of Cell: 14
# Key Cell ID: CCGTTGCTACGG - Assigned Cluster: 8 - Number of Cell: 14
# Key Cell ID: CTACCCGTAAGA - Assigned Cluster: 8 - Number of Cell: 14
# Key Cell ID: CACAACCTCCTG - Assigned Cluster: 8 - Number of Cell: 4
# Key Cell ID: TAACAGCGTTCG - Assigned Cluster: 9 - Number of Cell: 14
# Key Cell ID: TTAATACCAACT - Assigned Cluster: 9 - Number of Cell: 14
# Key Cell ID: GGCTCATTGCTG - Assigned Cluster: 9 - Number of Cell: 14
# Key Cell ID: CCCATATATCGG - Assigned Cluster: 9 - Number of Cell: 14
# Key Cell ID: GTAACTTGCGAT - Assigned Cluster: 9 - Number of Cell: 14
# Key Cell ID: GTGGTTTTCCGG - Assigned Cluster: 9 - Number of Cell: 14
# Key Cell ID: TCGAAAACGTAG - Assigned Cluster: 9 - Number of Cell: 14
# Key Cell ID: GCATCGCGAAAC - Assigned Cluster: 9 - Number of Cell: 14
# Key Cell ID: GGATAAGGGATC - Assigned Cluster: 9 - Number of Cell: 14
# Key Cell ID: GCTGGTTAGTTT - Assigned Cluster: 9 - Number of Cell: 14
# Key Cell ID: CGTTAGTGAGAA - Assigned Cluster: 9 - Number of Cell: 14
# Key Cell ID: CGCAAACTAGAT - Assigned Cluster: 9 - Number of Cell: 14
# Key Cell ID: AAGCGAAGGATG - Assigned Cluster: 9 - Number of Cell: 14
# Key Cell ID: TACGGAAATATC - Assigned Cluster: 9 - Number of Cell: 14
# Key Cell ID: CCTGCGCGAGTN - Assigned Cluster: 9 - Number of Cell: 4

# %%
my_vdata = shrunken_mtx(mtx=mtx, meta=meta, num_to_select=10)
my_vdata.A_clusTocell_dic_generator()
my_vdata.B_cellTogene_dic_generator()

print(my_vdata.num_to_select)
my_vdata.C_random_selector(num_to_select=45)
print(my_vdata.num_to_select)

my_vdata.D_avg_gene()
my_vdata.E_briefing()
# Out:
# 10
# 45
# Key Cell ID: TGAACCAAGATG - Assigned Cluster: 0 - Number of Cell: 45
# Key Cell ID: ACGTTACGGAGT - Assigned Cluster: 0 - Number of Cell: 45
# Key Cell ID: AGTTTCACTAAN - Assigned Cluster: 0 - Number of Cell: 45
# Key Cell ID: AAGAGGCGCTTT - Assigned Cluster: 0 - Number of Cell: 45
# Key Cell ID: TTGGTATTTTGA - Assigned Cluster: 0 - Number of Cell: 20
# Key Cell ID: ATCCTATGCGAG - Assigned Cluster: 1 - Number of Cell: 45
# Key Cell ID: ATACGATGAAAA - Assigned Cluster: 1 - Number of Cell: 45
# Key Cell ID: TGGTTTGCTTTT - Assigned Cluster: 1 - Number of Cell: 45
# Key Cell ID: AGTTTGTATTAG - Assigned Cluster: 1 - Number of Cell: 45
# Key Cell ID: AGTCACTATTGC - Assigned Cluster: 1 - Number of Cell: 20
# Key Cell ID: CGGTGCGCATAG - Assigned Cluster: 10 - Number of Cell: 45
# Key Cell ID: GCAGTGGAATCC - Assigned Cluster: 10 - Number of Cell: 45
# Key Cell ID: CGTGCGGAAACG - Assigned Cluster: 10 - Number of Cell: 45
# Key Cell ID: TTTTGGTTCAAC - Assigned Cluster: 10 - Number of Cell: 45
# Key Cell ID: ACGCCTCGGACT - Assigned Cluster: 10 - Number of Cell: 20
# Key Cell ID: AACGTAGTCCAC - Assigned Cluster: 11 - Number of Cell: 45
# Key Cell ID: CAAGGGCTAGAG - Assigned Cluster: 11 - Number of Cell: 45
# Key Cell ID: GTATTCTCATCN - Assigned Cluster: 11 - Number of Cell: 42
# Key Cell ID: CGGAAGATCCTC - Assigned Cluster: 12 - Number of Cell: 45
# Key Cell ID: GCGGGATTTTGA - Assigned Cluster: 12 - Number of Cell: 12
# Key Cell ID: TGTCGATTGCTG - Assigned Cluster: 2 - Number of Cell: 45
# Key Cell ID: AATATCACTTCG - Assigned Cluster: 2 - Number of Cell: 45
# Key Cell ID: TACGACAGATAA - Assigned Cluster: 2 - Number of Cell: 45
# Key Cell ID: TGACAGTTACCN - Assigned Cluster: 2 - Number of Cell: 45
# Key Cell ID: TTGTCCACTCCT - Assigned Cluster: 2 - Number of Cell: 20
# Key Cell ID: CTAAGCGGAGGG - Assigned Cluster: 3 - Number of Cell: 45
# Key Cell ID: GATTAGCCGTCA - Assigned Cluster: 3 - Number of Cell: 45
# Key Cell ID: AGTCCAGATGGG - Assigned Cluster: 3 - Number of Cell: 45
# Key Cell ID: GTGAAGTAGCAT - Assigned Cluster: 3 - Number of Cell: 45
# Key Cell ID: ATGTCTGATTCN - Assigned Cluster: 3 - Number of Cell: 20
# Key Cell ID: AGGGAAGGAAGC - Assigned Cluster: 4 - Number of Cell: 45
# Key Cell ID: GCAGCAGGAGGT - Assigned Cluster: 4 - Number of Cell: 45
# Key Cell ID: CCCGCCTTTACC - Assigned Cluster: 4 - Number of Cell: 45
# Key Cell ID: TTTGATGAAGTG - Assigned Cluster: 4 - Number of Cell: 45
# Key Cell ID: GCATGAGAGTAA - Assigned Cluster: 4 - Number of Cell: 20
# Key Cell ID: ACAGCCCCCTAN - Assigned Cluster: 5 - Number of Cell: 45
# Key Cell ID: GTTGTTGGTGCN - Assigned Cluster: 5 - Number of Cell: 45
# Key Cell ID: GTGTGCTAGACA - Assigned Cluster: 5 - Number of Cell: 45
# Key Cell ID: TATTCACGATTT - Assigned Cluster: 5 - Number of Cell: 45
# Key Cell ID: CGAAGGCTGTCN - Assigned Cluster: 5 - Number of Cell: 20
# Key Cell ID: ACGCCACGAGGC - Assigned Cluster: 6 - Number of Cell: 45
# Key Cell ID: GATCACCGGGAG - Assigned Cluster: 6 - Number of Cell: 45
# Key Cell ID: TTCCTATTACCG - Assigned Cluster: 6 - Number of Cell: 45
# Key Cell ID: TCATAAATCCGT - Assigned Cluster: 6 - Number of Cell: 45
# Key Cell ID: ATTGAGGACATC - Assigned Cluster: 6 - Number of Cell: 20
# Key Cell ID: CTTGGCTCTCGC - Assigned Cluster: 7 - Number of Cell: 45
# Key Cell ID: ATCTGAGAGATT - Assigned Cluster: 7 - Number of Cell: 45
# Key Cell ID: CAGCGAAATGTC - Assigned Cluster: 7 - Number of Cell: 45
# Key Cell ID: CGGTATCGCCTT - Assigned Cluster: 7 - Number of Cell: 45
# Key Cell ID: ATTGACGTGGAG - Assigned Cluster: 7 - Number of Cell: 20
# Key Cell ID: ACCTGTCGTTTG - Assigned Cluster: 8 - Number of Cell: 45
# Key Cell ID: GCTGCTGCCGGN - Assigned Cluster: 8 - Number of Cell: 45
# Key Cell ID: ACCGAGCCGTGC - Assigned Cluster: 8 - Number of Cell: 45
# Key Cell ID: TCCTCGCTCGGC - Assigned Cluster: 8 - Number of Cell: 45
# Key Cell ID: CAGTTCTAATGG - Assigned Cluster: 8 - Number of Cell: 20
# Key Cell ID: CGAGCGCCTACN - Assigned Cluster: 9 - Number of Cell: 45
# Key Cell ID: TAGAAGATAATA - Assigned Cluster: 9 - Number of Cell: 45
# Key Cell ID: GCGTAGCCACTT - Assigned Cluster: 9 - Number of Cell: 45
# Key Cell ID: GCCGGGTTTGGA - Assigned Cluster: 9 - Number of Cell: 45
# Key Cell ID: CGTTAGTGAGAA - Assigned Cluster: 9 - Number of Cell: 20

# %%
# additional methods only in child class
my_vdata.tSNE_input()

# %%
# additional methods only in child class
my_vdata.tSNE_output()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
