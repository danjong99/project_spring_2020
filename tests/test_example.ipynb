# %%
# %pwd
# Out:
# '/Users/kangb3/github/project_spring_2020'

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from bk_packages.shrink_mtx import rand_draw

# %%
#### Read Meta Files - read as list of lists
meta = []
with open("tests/metatable.txt") as f_obj:
     for line in f_obj:
        res = line.replace('"','').strip('\n').split('\t')
        meta.append(res)
    
### Insert one element in the 1th list of the meta data
meta[0].insert(0,'rowname')
    
### Read matrix file - read as list of lists
mtx = []
with open("tests/exprs_mtx.txt") as f_obj:
    for line in f_obj:
        res = line.replace('"','').strip('\n').split('\t')
        mtx.append(res)
    
### Insert one element in the 1th list of the mtx
mtx[0].insert(0,'gene')

# %%
### generate a test object by calling rand_draw
my_data = rand_draw(mtx=mtx, meta=meta, num_to_select=20)

# %%
### A to D methods are essential
my_data.A_clustocell_dic_generator()
my_data.B_celltogene_dic_generator()

# the initial vaule of num_to_select can be replaced.
print(my_data.num_to_select)
my_data.C_random_selector(num_to_select=30)
print(my_data.num_to_select)

# Average gene expression values of chosen cells
my_data.D_avg_gene()
# Out:
# 20
# 30

# %%
# Brief report
my_data.E_briefing()
# Out:
# Key Cell ID: ACGTGCCTACTA - Assigned Cluster: 0 - Number of Cell: 30
# Key Cell ID: AAAGCTACCAAC - Assigned Cluster: 0 - Number of Cell: 30
# Key Cell ID: CCTTAAAGCCCA - Assigned Cluster: 0 - Number of Cell: 30
# Key Cell ID: GTCACGCCGCCN - Assigned Cluster: 0 - Number of Cell: 30
# Key Cell ID: GTTCACCCGAAC - Assigned Cluster: 0 - Number of Cell: 30
# Key Cell ID: TCCAGCCAGAGN - Assigned Cluster: 0 - Number of Cell: 30
# Key Cell ID: CATATAGCTGGG - Assigned Cluster: 0 - Number of Cell: 20
# Key Cell ID: AGTCCTTGCAGN - Assigned Cluster: 1 - Number of Cell: 30
# Key Cell ID: GATCTTTGAGAT - Assigned Cluster: 1 - Number of Cell: 30
# Key Cell ID: GAAACCTTGCAG - Assigned Cluster: 1 - Number of Cell: 30
# Key Cell ID: TGCGTAATGCAN - Assigned Cluster: 1 - Number of Cell: 30
# Key Cell ID: CATAACATGTCG - Assigned Cluster: 1 - Number of Cell: 30
# Key Cell ID: TTTTGAACGTTA - Assigned Cluster: 1 - Number of Cell: 30
# Key Cell ID: CTGATTTAGTCT - Assigned Cluster: 1 - Number of Cell: 20
# Key Cell ID: AAACACCGGAAT - Assigned Cluster: 10 - Number of Cell: 30
# Key Cell ID: TGCAAAATTCTT - Assigned Cluster: 10 - Number of Cell: 30
# Key Cell ID: AGTATTTGTGTA - Assigned Cluster: 10 - Number of Cell: 30
# Key Cell ID: CAGTTCTAATAC - Assigned Cluster: 10 - Number of Cell: 30
# Key Cell ID: TTTTGGTTCAAC - Assigned Cluster: 10 - Number of Cell: 30
# Key Cell ID: CGTCACGCAGGC - Assigned Cluster: 10 - Number of Cell: 30
# Key Cell ID: CGTGCGGAAACG - Assigned Cluster: 10 - Number of Cell: 20
# Key Cell ID: GAGGTCTCACTA - Assigned Cluster: 11 - Number of Cell: 30
# Key Cell ID: GATCCACCATTC - Assigned Cluster: 11 - Number of Cell: 30
# Key Cell ID: ACAGCCTTATTT - Assigned Cluster: 11 - Number of Cell: 30
# Key Cell ID: GGTCCCGGAACC - Assigned Cluster: 11 - Number of Cell: 30
# Key Cell ID: ATGTTGCTGCAG - Assigned Cluster: 11 - Number of Cell: 12
# Key Cell ID: GATGGACGCGCC - Assigned Cluster: 12 - Number of Cell: 30
# Key Cell ID: CGAATCGTTAAG - Assigned Cluster: 12 - Number of Cell: 27
# Key Cell ID: GTGCAGCCGAAC - Assigned Cluster: 2 - Number of Cell: 30
# Key Cell ID: GCGGGCCTTGCA - Assigned Cluster: 2 - Number of Cell: 30
# Key Cell ID: ATATACATGCAA - Assigned Cluster: 2 - Number of Cell: 30
# Key Cell ID: GTTCTTTTGGTA - Assigned Cluster: 2 - Number of Cell: 30
# Key Cell ID: TAATGTCGATTN - Assigned Cluster: 2 - Number of Cell: 30
# Key Cell ID: GGTGCTTAGTGG - Assigned Cluster: 2 - Number of Cell: 30
# Key Cell ID: GCTGAGAGATCG - Assigned Cluster: 2 - Number of Cell: 20
# Key Cell ID: GTTTTTTAGCCG - Assigned Cluster: 3 - Number of Cell: 30
# Key Cell ID: CCCTATAGGCCT - Assigned Cluster: 3 - Number of Cell: 30
# Key Cell ID: CCGACTGTATTG - Assigned Cluster: 3 - Number of Cell: 30
# Key Cell ID: CTTAGGCTGGCN - Assigned Cluster: 3 - Number of Cell: 30
# Key Cell ID: CTAAGCGGAGGG - Assigned Cluster: 3 - Number of Cell: 30
# Key Cell ID: AATCTGGCGTCC - Assigned Cluster: 3 - Number of Cell: 30
# Key Cell ID: TTCCCCGAGAGN - Assigned Cluster: 3 - Number of Cell: 20
# Key Cell ID: GAGATTCCCTTN - Assigned Cluster: 4 - Number of Cell: 30
# Key Cell ID: GATCCTGTCACT - Assigned Cluster: 4 - Number of Cell: 30
# Key Cell ID: AGGGCATGGTAG - Assigned Cluster: 4 - Number of Cell: 30
# Key Cell ID: ACCCGCAACACA - Assigned Cluster: 4 - Number of Cell: 30
# Key Cell ID: TAGTGATGATCN - Assigned Cluster: 4 - Number of Cell: 30
# Key Cell ID: GGGCAAAATGTN - Assigned Cluster: 4 - Number of Cell: 30
# Key Cell ID: CATTAGCATCTT - Assigned Cluster: 4 - Number of Cell: 20
# Key Cell ID: AACCTCGATTCC - Assigned Cluster: 5 - Number of Cell: 30
# Key Cell ID: ATTGTGCCCGTG - Assigned Cluster: 5 - Number of Cell: 30
# Key Cell ID: CCGCACCCGAGG - Assigned Cluster: 5 - Number of Cell: 30
# Key Cell ID: ATCATGAGGCAG - Assigned Cluster: 5 - Number of Cell: 30
# Key Cell ID: TATAAGCCTTAA - Assigned Cluster: 5 - Number of Cell: 30
# Key Cell ID: GCTCAATAACGC - Assigned Cluster: 5 - Number of Cell: 30
# Key Cell ID: CACCCCACGCCN - Assigned Cluster: 5 - Number of Cell: 20
# Key Cell ID: CTGGCTGCAGGT - Assigned Cluster: 6 - Number of Cell: 30
# Key Cell ID: CCGGTGCGGTTG - Assigned Cluster: 6 - Number of Cell: 30
# Key Cell ID: GTAAAATCATGG - Assigned Cluster: 6 - Number of Cell: 30
# Key Cell ID: ACGAAATATGAC - Assigned Cluster: 6 - Number of Cell: 30
# Key Cell ID: GAGCAGCCTGGT - Assigned Cluster: 6 - Number of Cell: 30
# Key Cell ID: ATGTAAGGAGAC - Assigned Cluster: 6 - Number of Cell: 30
# Key Cell ID: GTGGTTTGAGAT - Assigned Cluster: 6 - Number of Cell: 20
# Key Cell ID: CAGTAAGCACCN - Assigned Cluster: 7 - Number of Cell: 30
# Key Cell ID: ACCAGATCTATN - Assigned Cluster: 7 - Number of Cell: 30
# Key Cell ID: AGAGGCCAGTTG - Assigned Cluster: 7 - Number of Cell: 30
# Key Cell ID: GCTCGGACTATG - Assigned Cluster: 7 - Number of Cell: 30
# Key Cell ID: TATGCGTGCTCC - Assigned Cluster: 7 - Number of Cell: 30
# Key Cell ID: GCGACGATGGAT - Assigned Cluster: 7 - Number of Cell: 30
# Key Cell ID: ATACCCCCAGCC - Assigned Cluster: 7 - Number of Cell: 20
# Key Cell ID: ATGTGGCTAGTG - Assigned Cluster: 8 - Number of Cell: 30
# Key Cell ID: GGATGGAGACGG - Assigned Cluster: 8 - Number of Cell: 30
# Key Cell ID: ATTCAAAGTACA - Assigned Cluster: 8 - Number of Cell: 30
# Key Cell ID: TTTGAAAGGGGT - Assigned Cluster: 8 - Number of Cell: 30
# Key Cell ID: GATGGTGGGCAA - Assigned Cluster: 8 - Number of Cell: 30
# Key Cell ID: CCAAGTTGTTCG - Assigned Cluster: 8 - Number of Cell: 30
# Key Cell ID: TGACCTTTGGAT - Assigned Cluster: 8 - Number of Cell: 20
# Key Cell ID: ATAACGTAAGAG - Assigned Cluster: 9 - Number of Cell: 30
# Key Cell ID: ACTACAGTTCAG - Assigned Cluster: 9 - Number of Cell: 30
# Key Cell ID: GCATCGCGAAAC - Assigned Cluster: 9 - Number of Cell: 30
# Key Cell ID: TACGTGTACAAC - Assigned Cluster: 9 - Number of Cell: 30
# Key Cell ID: CTAGGCAGGTGN - Assigned Cluster: 9 - Number of Cell: 30
# Key Cell ID: CTGACGCGAGCG - Assigned Cluster: 9 - Number of Cell: 30
# Key Cell ID: AAACTCGCGAAA - Assigned Cluster: 9 - Number of Cell: 20

# %%
# tSNE of input data
my_data.tSNE_input()

# %%
# tSNE after random draw and merge
my_data.tSNE_output()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
